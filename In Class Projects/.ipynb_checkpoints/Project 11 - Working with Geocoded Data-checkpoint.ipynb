# %% [markdown]
# # Project 11 - Working with Geocoded Data

# %%
# !pip install GDAL-3.1.4-cp38-cp38-win_amd64.whl
# !pip install Fiona-1.8.17-cp38-cp38-win_amd64.whl
# !pip install Shapely-1.7.1-cp38-cp38-win_amd64.whl
# !pip install geopandas
# Out:
# Processing c:\git\econ-611\in class projects\gdal-3.1.4-cp38-cp38-win_amd64.whl
# GDAL is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing c:\git\econ-611\in class projects\fiona-1.8.17-cp38-cp38-win_amd64.whl
# Requirement already satisfied: six>=1.7 in c:\programdata\anaconda3\lib\site-packages (from Fiona==1.8.17) (1.15.0)
# Requirement already satisfied: click>=4.0 in c:\users\brand\appdata\roaming\python\python38\site-packages (from Fiona==1.8.17) (6.7)
# Requirement already satisfied: gdal~=3.1.2 in c:\programdata\anaconda3\lib\site-packages (from Fiona==1.8.17) (3.1.4)
# Requirement already satisfied: cligj>=0.5 in c:\programdata\anaconda3\lib\site-packages (from Fiona==1.8.17) (0.7.2)
# Requirement already satisfied: attrs>=17 in c:\programdata\anaconda3\lib\site-packages (from Fiona==1.8.17) (20.3.0)
# Requirement already satisfied: munch in c:\programdata\anaconda3\lib\site-packages (from Fiona==1.8.17) (2.5.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\programdata\anaconda3\lib\site-packages (from Fiona==1.8.17) (1.1.1)
# Fiona is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing c:\git\econ-611\in class projects\shapely-1.7.1-cp38-cp38-win_amd64.whl
# Shapely is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Requirement already satisfied: geopandas in c:\programdata\anaconda3\lib\site-packages (0.10.2)
# Requirement already satisfied: pandas>=0.25.0 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.2.4)
# Requirement already satisfied: pyproj>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (3.2.1)
# Requirement already satisfied: shapely>=1.6 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.8.17)
# Requirement already satisfied: click>=4.0 in c:\users\brand\appdata\roaming\python\python38\site-packages (from fiona>=1.8->geopandas) (6.7)
# Requirement already satisfied: six>=1.7 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: gdal~=3.1.2 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (3.1.4)
# Requirement already satisfied: cligj>=0.5 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: munch in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=17 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (1.20.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from pyproj>=2.2.0->geopandas) (2020.12.5)

# %%
# !pip install datadotworld --user
# Out:
# Requirement already satisfied: datadotworld in c:\users\brand\appdata\roaming\python\python38\site-packages (1.8.0)
# Requirement already satisfied: datapackage<2.0a,>=1.6.2 in c:\users\brand\appdata\roaming\python\python38\site-packages (from datadotworld) (1.15.2)
# Requirement already satisfied: configparser<4.0a,>=3.5.0 in c:\users\brand\appdata\roaming\python\python38\site-packages (from datadotworld) (3.8.1)
# Requirement already satisfied: tabulator>=1.22.0 in c:\users\brand\appdata\roaming\python\python38\site-packages (from datadotworld) (1.53.5)
# Requirement already satisfied: click<7.0a,>=6.0 in c:\users\brand\appdata\roaming\python\python38\site-packages (from datadotworld) (6.7)
# Requirement already satisfied: tableschema<2.0a,>=1.5.2 in c:\users\brand\appdata\roaming\python\python38\site-packages (from datadotworld) (1.20.2)
# Requirement already satisfied: certifi>=2017.04.17 in c:\programdata\anaconda3\lib\site-packages (from datadotworld) (2020.12.5)
# Requirement already satisfied: urllib3<2.0a,>=1.15 in c:\programdata\anaconda3\lib\site-packages (from datadotworld) (1.26.4)
# Requirement already satisfied: requests<3.0a,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from datadotworld) (2.25.1)
# Requirement already satisfied: python-dateutil<3.0a,>=2.6.0 in c:\programdata\anaconda3\lib\site-packages (from datadotworld) (2.8.1)
# Requirement already satisfied: six<2.0a,>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from datadotworld) (1.15.0)
# Requirement already satisfied: jsonschema>=2.5 in c:\programdata\anaconda3\lib\site-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (3.2.0)
# Requirement already satisfied: unicodecsv>=0.14 in c:\programdata\anaconda3\lib\site-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (0.14.1)
# Requirement already satisfied: chardet>=3.0 in c:\programdata\anaconda3\lib\site-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (4.0.0)
# Requirement already satisfied: jsonpointer>=1.10 in c:\users\brand\appdata\roaming\python\python38\site-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (2.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (0.17.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.5->datapackage<2.0a,>=1.6.2->datadotworld) (52.0.0.post20210125)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0a,>=2.0.0->datadotworld) (2.10)
# Requirement already satisfied: cached-property>=1.5 in c:\users\brand\appdata\roaming\python\python38\site-packages (from tableschema<2.0a,>=1.5.2->datadotworld) (1.5.2)
# Requirement already satisfied: rfc3986>=1.1.0 in c:\users\brand\appdata\roaming\python\python38\site-packages (from tableschema<2.0a,>=1.5.2->datadotworld) (1.5.0)
# Requirement already satisfied: isodate>=0.5.4 in c:\users\brand\appdata\roaming\python\python38\site-packages (from tableschema<2.0a,>=1.5.2->datadotworld) (0.6.0)
# Requirement already satisfied: jsonlines>=1.1 in c:\programdata\anaconda3\lib\site-packages (from tabulator>=1.22.0->datadotworld) (2.0.0)
# Requirement already satisfied: boto3>=1.9 in c:\users\brand\appdata\roaming\python\python38\site-packages (from tabulator>=1.22.0->datadotworld) (1.20.6)
# Requirement already satisfied: xlrd>=1.0 in c:\programdata\anaconda3\lib\site-packages (from tabulator>=1.22.0->datadotworld) (2.0.1)
# Requirement already satisfied: openpyxl>=2.6 in c:\programdata\anaconda3\lib\site-packages (from tabulator>=1.22.0->datadotworld) (3.0.7)
# Requirement already satisfied: ijson>=3.0.3 in c:\programdata\anaconda3\lib\site-packages (from tabulator>=1.22.0->datadotworld) (3.1.4)
# Requirement already satisfied: sqlalchemy>=0.9.6 in c:\programdata\anaconda3\lib\site-packages (from tabulator>=1.22.0->datadotworld) (1.4.7)
# Requirement already satisfied: linear-tsv>=1.0 in c:\programdata\anaconda3\lib\site-packages (from tabulator>=1.22.0->datadotworld) (1.1.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (0.10.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.6 in c:\programdata\anaconda3\lib\site-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (1.23.6)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\lib\site-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld) (1.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=0.9.6->tabulator>=1.22.0->datadotworld) (1.0.0)

# %%
# Import all modules that will be used
import geopandas
import numpy as np
import pandas as pd

# Won't actually use datetime directly. Since the dataframe index will use 
# data formatted as datetime64, import it in case need to use the datetime
# module to troubleshoot later 
import datetime

# Could technically call many of the submodules from matplotlib using mpl., 
# but for convenience, explicitly import submodules. These will be used for 
# constructing visualizations
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm

# If choose to make a dynamic visualization for the homework
from matplotlib.animation import FuncAnimation
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.ticker as mtick
import datadotworld as dw

# %%
def import_geo_data(filename, index_col = "Date", FIPS_name = "FIPS"):
    # Import county level shapefile
    map_data = geopandas.read_file(filename = filename,
                                  index_col = index_col)
    # Rename fips code to match variable name in COVID-19 data
    map_data.rename(columns = {"State":"state"}, inplace = True)
    # Combines statefips and county fips to create single fips value
    # that indicates state and county
    
    # Concatenates string
    map_data[FIPS_name] = map_data["STATEFP"].astype(str) +\
        map_data["COUNTYFP"].astype(str)
    map_data[FIPS_name] = map_data[FIPS_name].astype(np.int64)
    map_data.set_index(FIPS_name, inplace = True)
    
    return map_data

# %%
# Include this dictionary to conveniently cross reference state names and
# state abbreviations.
state_dict = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ',
    'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO', 'Connecticut': 'CT', 
    'Delaware': 'DE', 'District of Columbia': 'DC', 'Florida': 'FL', 
    'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL',
    'Indiana': 'IN', 'Iowa': 'IA','Kansas': 'KS', 'Kentucky': 'KY',
    'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA',
    'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH',
    'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC',
    'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
    'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI',
    'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX',
    'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA',
    'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'}

plt.rcParams['axes.ymargin'] = 0
plt.rcParams['axes.xmargin'] = 0
plt.rcParams.update({'font.size': 32})

# %%
fips_name = "fips_code"
map_data = import_geo_data(
    filename = "countiesWithStatesAndPopulation.shp",
    index_col = "Date", FIPS_name = fips_name)

# %%
map_data
# Out:
#            STATEFP COUNTYFP  COUNTYNS        AFFGEOID       NAME LSAD  \
# fips_code
# 21007           21      007  00516850  0500000US21007    Ballard   06
# 21017           21      017  00516855  0500000US21017    Bourbon   06
# 21031           21      031  00516862  0500000US21031     Butler   06
# 21065           21      065  00516879  0500000US21065     Estill   06
# 21069           21      069  00516881  0500000US21069    Fleming   06
# ...            ...      ...       ...             ...        ...  ...
# 31073           31      073  00835858  0500000US31073     Gosper   06
# 39075           39      075  01074050  0500000US39075     Holmes   06
# 48171           48      171  01383871  0500000US48171  Gillespie   06
# 55079           55      079  01581100  0500000US55079  Milwaukee   06
# 26139           26      139  01623012  0500000US26139     Ottawa   06
#
#                 ALAND      AWATER  Population      state  \
# fips_code
# 21007       639387454    69473325      7888.0   Kentucky
# 21017       750439351     4829777     19788.0   Kentucky
# 21031      1103571974    13943044     12879.0   Kentucky
# 21065       655509930     6516335     14106.0   Kentucky
# 21069       902727151     7182793     14581.0   Kentucky
# ...               ...         ...         ...        ...
# 31073      1186616237    11831826      1990.0   Nebraska
# 39075      1094405866     3695230     43960.0       Ohio
# 48171      2740719114     9012764     26988.0      Texas
# 55079       625440563  2455383635    945726.0  Wisconsin
# 26139      1459502408  2765830983    291830.0   Michigan
#
#                                                     geometry
# fips_code
# 21007      POLYGON ((-89.18137 37.04630, -89.17938 37.053...
# 21017      POLYGON ((-84.44266 38.28324, -84.44114 38.283...
# 21031      POLYGON ((-86.94486 37.07341, -86.94346 37.074...
# 21065      POLYGON ((-84.12662 37.64540, -84.12483 37.646...
# 21069      POLYGON ((-83.98428 38.44549, -83.98246 38.450...
# ...                                                      ...
# 31073      POLYGON ((-100.09510 40.43866, -100.08937 40.4...
# 39075      POLYGON ((-82.22066 40.66758, -82.19327 40.667...
# 48171      POLYGON ((-99.30400 30.49983, -99.28234 30.499...
# 55079      POLYGON ((-88.06959 42.86726, -88.06959 42.872...
# 26139      POLYGON ((-86.26432 43.11830, -86.25103 43.118...
#
# [3142 rows x 11 columns]

# %%
fig, ax = plt.subplots(figsize = (30, 20))
map_data[map_data["state"] == "Oregon"].plot(column = "Population", ax = ax)
ax.set_title("Oregon", fontsize = 50)
# Out:
# Text(0.5, 1.0, 'Oregon')

# %%
def import_covid_data(FIPS_name):
    dataset = dw.load_dataset(
        "associatedpress/johns-hopkins-coronavirus-case-tracker",
        auto_update = True)
    covid_data = dataset.dataframes["2_cases_and_deaths_by_county_timeseries"]
    covid_data = covid_data[covid_data[FIPS_name] < 57000]
    covid_data = covid_data[covid_data[FIPS_name] > 0]
    
    # Drops leading zeroes and converts to int
    covid_data[FIPS_name] = covid_data[FIPS_name].astype(np.int64)
    # Formats the data columns as datetime for readability
    covid_data["date"] = pd.to_datetime(covid_data["date"])
    covid_data.set_index([FIPS_name, "date"], inplace = True)
    # Creates new column
    covid_data["state_abr"] = ""
    
    for state, abr in state_dict.items():
        # Calls a slice of the df by state and fills with abreviation
        covid_data.loc[covid_data["state"] == state, "state_abr"] = abr
    covid_data["Location"] = covid_data["location_name"] + ", " + \
                                        covid_data["state_abr"]
    
    return covid_data

# %%
covid_data = import_covid_data(FIPS_name = fips_name)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-7e74fd27bc03> in <module>
# ----> 1 covid_data = import_covid_data(FIPS_name = fips_name)
#
# <ipython-input-9-a476a4953614> in import_covid_data(FIPS_name)
#       1 def import_covid_data(FIPS_name):
# ----> 2     dataset = dw.load_dataset(
#       3         "associatedpress/johns-hopkins-coronavirus-case-tracker",
#       4         auto_update = True)
#       5     covid_data = dataset.dataframes["2_cases_and_deaths_by_county_timeseries"]
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\__init__.py in load_dataset(dataset_key, force_update, auto_update, profile, **kwargs)
#      96     ['changelog', 'datadotworldbballstats', 'datadotworldbballteam']
#      97     """
# ---> 98     return _get_instance(profile, **kwargs). \
#      99         load_dataset(dataset_key,
#     100                      force_update=force_update,
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\__init__.py in _get_instance(profile, **kwargs)
#      58                 if profile == 'default'
#      59                 else FileConfig(profile=profile))
# ---> 60         instance = DataDotWorld(config=config_param)
#      61         __instances[profile] = instance
#      62     return instance
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\datadotworld.py in __init__(self, config)
#      55     def __init__(self, config=None):
#      56         self._config = config or ChainedConfig()
# ---> 57         self.api_client = RestApiClient(self._config)
#      58
#      59     def query(self, dataset_key, query, query_type="sql", parameters=None):
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\client\api.py in __init__(self, config)
#      54             host=self._host,
#      55             header_name='Authorization',
# ---> 56             header_value='Bearer {}'.format(self._config.auth_token))
#      57         swagger_client.user_agent = _user_agent()
#      58
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\config.py in __getattribute__(self, item)
#     210         """Delegates requests to config objects in the chain
#     211         """
# --> 212         return object.__getattribute__(self, '_first_not_none')(
#     213             object.__getattribute__(self, '_config_chain'),
#     214             lambda c: c.__getattribute__(item))
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\config.py in _first_not_none(seq, supplier_func)
#     225         """
#     226         for i in seq:
# --> 227             obj = supplier_func(i)
#     228             if obj is not None:
#     229                 return obj
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\config.py in <lambda>(c)
#     212         return object.__getattribute__(self, '_first_not_none')(
#     213             object.__getattribute__(self, '_config_chain'),
# --> 214             lambda c: c.__getattribute__(item))
#     215
#     216     @staticmethod
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\config.py in auth_token(self)
#     123     @property
#     124     def auth_token(self):
# --> 125         self.__validate_config()
#     126         return self._config_parser.get(self._section, 'auth_token')
#     127
#
# ~\AppData\Roaming\Python\Python38\site-packages\datadotworld\config.py in __validate_config(self)
#     145     def __validate_config(self):
#     146         if not path.isfile(self._config_file_path):
# --> 147             raise RuntimeError(
#     148                 'Configuration file not found at {}.'
#     149                 'To fix this issue, run dw configure'.format(
#
# RuntimeError: Configuration file not found at C:\Users\brand/.dw/config.To fix this issue, run dw configure

# %%
covid_data

# %%
# Shows covid data for specific state up to date
covid_data[covid_data["state"] == "Oregon"].groupby("date").sum()[["new_cases", "new_deaths"]]

# %%
fig, ax = plt.subplots(figsize = (20, 14))
covid_data.groupby("date").sum().loc["2021-03-01":, ["new_cases", "New_deaths"]].plot.line(
    secondary_y = "new_deaths", 
    ax = ax)
ax.set_title("United States")

# %%
fig,ax = plt.subplots(figsize = (20,14))
covid_data.groupby("date").sum().loc[:,["new_cases", "new_deaths"]].rolling(7).mean().plot.line(
    secondary_y = "new_deaths", ax = ax)
ax.set_title("United States")

# %%
# Builds a new geo dataframe and stacks it for each day in covid data
def create_merged_geo_dataframe(data, map_date, dates):
    data_frame_initialized = False
    
    counties = data.groupby("fips_code").mean().index
    for date in dates:
        agg_df = map_data[map_data.index.isin(counties)]
        agg_df["date"] = date
        if data_frame_initialized == False:
            # Takes DF, transforms it to geo DF and uses coordinate 
            # system from map data
            matching_gpd = geopands.GeoDataFrame(agg_df,
                                                 crs = map_data.crs)
            data_frame_initialized = True
        # Appends new Df to new DF
        else:
            matching_gpd = matching_gpd.append(
                agg_df,
                ignore_index = False)
    
    matching_gpd.reset_index(inplace = True)
    matching_gpd.set_index(["fips_code", "date"], inplace = True)
    matching_gpd.drop("state", axis = 1, inplace = True)
    
    matching_gpd = pd.concat([matching_gpd, data], axis = 1)
            
    return matching_gpd

# %%
dates = sorted(list(set(covid_data.index.get_level_values("date"))))
covid_data = create_merged_geo_dataframe(covid_data, map_data, dates)

# %%
covid_data

# %%
def create_new_vars(covid_data):
    for key in ["cases", "deaths"]:
        cap_key = key.title()
        covid_data.rename(columns = {"cumulative_" + key : "Total " + cap_key,
                                     "new_" + key: "Daily " + cap_key,
                                     "new_" + key + "_7_day_rolling_avg":"Daily " + cap_key + " 7 Day MA"},
                         inplace = True)
        
        covid_data[cap_key + " per Million"] = covid_data[
            "Total " + cap_key].fillna(0)\
            .div(covid_data["total_population"]).mul(10 ** 6)
        
        # The number of days passed as moving_average_days from rolling average
        covid_data["Daily " + cap_key + " per Million 7 Day MA"] = \
            covid_data["Daily " + cap_key + " 7 Day MA"]\
            .div(covid_data["total_population"]).mul(10 ** 6)
        

create_new_vars(covid_data)

# %%
covid_data

# %%
# Selects data by state
or_data = covid_data[covid_data["state"] == "Oregon"]

# Selects data by date
or_data = or_data[or_data.index.get_level_values("date") == "2021-11-15"]

# Plots data
fig, ax = plt.subplots(figsize = (20, 10))
key = "Daily Deaths per Million 7 Day MA"
or_data.plot(column = key, ax = ax) # Can also include , cmap = "Reds" to change colors on map to red
ax.set_title(key)

# %%
start_date = "01-01-2021"
end_date = dates[-1]

# %%
def select_data_within_bounds(data, minx, miny, maxx, maxy):
    data = data[data.bounds["maxx"] <= maxx]
    data = data[data.bounds["maxy"] <= maxy]
    data = data[data.bounds["minx"] >= minx]
    data = data[data.bounds["miny"] >= miny]
    
    return data

date = dates[-1]

if "map_bounded" not in locals():
    minx = covid_data[covid_data.index.get_level_values("date")== date].bounds["minx"].min()
    miny = covid_data[covid_data.index.get_level_values("date")== date].bounds["miny"].min()
    maxx = -58
    maxy = covid_data[covid_data.index.get_level_values("date")== date].bounds["maxy"].max()
    
    # Finds counties using one date and performs operation once instead of 
    # several hundred times
    bounded_data =  select_data_within_bounds(covid_data[covid_data.index.get_level_values("date")== date], minx, miny, maxx, maxy)
    counties = bounded_data.groupby("fips_code").mean().index
    covid_map_data =covid_data[covid_data.index.get_level_values("fips_code").isin(counties)]
    map_bounded = True

# %%
covid_map_data

# %%
covid_map_data.fillna(0, inplace = True)

# %%
fig, ax = plt.subplots(figsize = (20, 10))
plt.rcParams.update({"font.size": 30})
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
key = "Deaths per Million"
df = covid_map_data[covid_map_data.index.get_level_values("date")== date]
df.plot(ax = ax,
        column = key,
        linedwidth = 0.1,
        edgecolor = "lightgrey")
