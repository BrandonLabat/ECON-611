# %% [markdown]
# # Project 9 - Partial Correlations and Directed Acyclic Graphs

# %%
import random
import numpy as np
import pandas as pd

length = 10000
cols = ["P", "Q", "X", "Y", "Z"]
mu = 0
sigma = 5
# Creates a blank list
lst_dct = {col:[] for col in cols}

# %%
for i in range(length):
    lst_dct["P"].append(25 + np.random.normal(mu, 0.5 * sigma))
    lst_dct["Q"].append(50 + np.random.normal(mu, sigma))
    lst_dct["X"].append(3 * lst_dct["Q"][-1] + np.random.normal(mu, sigma))
    lst_dct["Y"].append(lst_dct["Q"][-1] * -1 + np.random.normal(mu, sigma))
    lst_dct["Z"].append(lst_dct["P"][-1] * 2 + 1.5 * lst_dct["X"][-1] 
                        - lst_dct["Y"][-1] * 2 + np.random.normal(mu, sigma))
    
df = pd.DataFrame(lst_dct)
keys = cols
df
# Out:
#               P          Q           X          Y           Z
# 0     24.929248  53.127950  156.482047 -45.597681  385.557695
# 1     26.857808  51.844959  150.015909 -57.125098  392.056993
# 2     23.806069  43.165442  122.982111 -46.544708  328.523294
# 3     25.948662  52.904925  154.365721 -42.144487  365.649805
# 4     20.086309  53.840919  157.786732 -50.601743  376.269253
# ...         ...        ...         ...        ...         ...
# 9995  25.057332  52.046976  153.938810 -53.190149  379.769981
# 9996  31.072113  55.237964  162.114702 -48.457935  399.037899
# 9997  22.509232  48.027059  150.693409 -50.298164  369.689439
# 9998  27.596678  45.846504  133.333660 -46.236811  347.258190
# 9999  26.020344  58.039850  174.169800 -63.482080  441.420619
#
# [10000 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({"font.size":26})
fig, ax = plt.subplots(figsize = (12, 8))
df.plot.scatter(x = "Q", 
                y = "Z", 
                c = "Y", 
                s = "X", 
                cmap = "viridis_r", 
                alpha = 0.8, 
                ax = ax)
# Out:
# <AxesSubplot:xlabel='Q', ylabel='Z'>

# %%
df.corr()
# Out:
#           P         Q         X         Y         Z
# P  1.000000  0.007542  0.007768  0.002508  0.146686
# Q  0.007542  1.000000  0.948314 -0.703874  0.914062
# X  0.007768  0.948314  1.000000 -0.666898  0.934067
# Y  0.002508 -0.703874 -0.666898  1.000000 -0.843377
# Z  0.146686  0.914062  0.934067 -0.843377  1.000000

# %% [markdown]
# ## Partial Correlation

# %%
import statsmodels.api as sm
# Takes keys - y variable
# Creates a residuals dictionary
residuals = {}
for y_var in df.keys():
    X_vars = list(df.keys())
    X_vars.remove(y_var)
    X = df[X_vars]
    X["Constant"] = 1
    y = df[[y_var]]
    model = sm.OLS(y, X)
    results = model.fit()
    print(results.summary())
    residuals[y_var] = results.resid
residuals = pd.DataFrame(residuals)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      P   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     2578.
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                -19856.
# No. Observations:               10000   AIC:                         3.972e+04
# Df Residuals:                    9995   BIC:                         3.976e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Q              0.0083      0.012      0.705      0.481      -0.015       0.031
# X             -0.3795      0.005    -73.778      0.000      -0.390      -0.369
# Y              0.5123      0.006     83.736      0.000       0.500       0.524
# Z              0.2526      0.002    101.530      0.000       0.248       0.257
# Constant      12.3712      0.217     57.117      0.000      11.947      12.796
# ==============================================================================
# Omnibus:                        0.689   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.709   Jarque-Bera (JB):                0.721
# Skew:                          -0.013   Prob(JB):                        0.697
# Kurtosis:                       2.967   Cond. No.                     5.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Q   R-squared:                       0.908
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                 2.481e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                -18244.
# No. Observations:               10000   AIC:                         3.650e+04
# Df Residuals:                    9995   BIC:                         3.653e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P              0.0060      0.009      0.705      0.481      -0.011       0.023
# X              0.2740      0.005     58.308      0.000       0.265       0.283
# Y             -0.0947      0.007    -14.078      0.000      -0.108      -0.081
# Z             -0.0018      0.003     -0.610      0.542      -0.008       0.004
# Constant       4.6759      0.207     22.580      0.000       4.270       5.082
# ==============================================================================
# Omnibus:                        2.262   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.323   Jarque-Bera (JB):                2.265
# Skew:                          -0.037   Prob(JB):                        0.322
# Kurtosis:                       2.996   Cond. No.                     5.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      X   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                 7.917e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                -24333.
# No. Observations:               10000   AIC:                         4.868e+04
# Df Residuals:                    9995   BIC:                         4.871e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P             -0.9291      0.013    -73.778      0.000      -0.954      -0.904
# Q              0.9263      0.016     58.308      0.000       0.895       0.957
# Y              0.9344      0.008    112.849      0.000       0.918       0.951
# Z              0.4628      0.003    151.331      0.000       0.457       0.469
# Constant       0.1039      0.390      0.266      0.790      -0.661       0.869
# ==============================================================================
# Omnibus:                        1.388   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.500   Jarque-Bera (JB):                1.403
# Skew:                          -0.013   Prob(JB):                        0.496
# Kurtosis:                       2.948   Cond. No.                     5.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                 2.270e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                -22115.
# No. Observations:               10000   AIC:                         4.424e+04
# Df Residuals:                    9995   BIC:                         4.428e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P              0.8048      0.010     83.736      0.000       0.786       0.824
# Q             -0.2054      0.015    -14.078      0.000      -0.234      -0.177
# X              0.5996      0.005    112.849      0.000       0.589       0.610
# Z             -0.3983      0.002   -202.112      0.000      -0.402      -0.394
# Constant      -0.4432      0.313     -1.418      0.156      -1.056       0.170
# ==============================================================================
# Omnibus:                        0.819   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.664   Jarque-Bera (JB):                0.839
# Skew:                           0.021   Prob(JB):                        0.657
# Kurtosis:                       2.984   Cond. No.                     5.81e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Z   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                 1.244e+05
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                -30228.
# No. Observations:               10000   AIC:                         6.047e+04
# Df Residuals:                    9995   BIC:                         6.050e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P              2.0101      0.020    101.530      0.000       1.971       2.049
# Q             -0.0202      0.033     -0.610      0.542      -0.085       0.045
# X              1.5043      0.010    151.331      0.000       1.485       1.524
# Y             -2.0173      0.010   -202.112      0.000      -2.037      -1.998
# Constant      -0.7133      0.704     -1.014      0.311      -2.093       0.666
# ==============================================================================
# Omnibus:                        0.326   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.850   Jarque-Bera (JB):                0.356
# Skew:                           0.007   Prob(JB):                        0.837
# Kurtosis:                       2.974   Cond. No.                     2.39e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
residuals
# Out:
#              P         Q         X         Y         Z
# 0    -2.526105  1.815758 -5.495518  5.415994  9.854887
# 1     1.222781  1.213651 -1.218189 -1.461485 -1.075868
# 2    -1.388500  0.845043 -3.531481  0.699421  3.359997
# 3     0.951441  2.456817 -0.471648  1.343347 -1.956911
# 4    -1.970368  1.709413 -0.376548 -0.025364 -1.741604
# ...        ...       ...       ...       ...       ...
# 9995  1.997030  0.701436  2.854265 -3.281621 -7.702777
# 9996  3.797145  2.099453  0.324182  0.036233 -3.213369
# 9997 -0.684649 -2.158635  2.927840 -1.233082 -2.026552
# 9998  1.418341  0.730446 -1.099380 -0.238489 -0.421129
# 9999  0.288154  0.283900 -0.485421 -0.695603  0.937891
#
# [10000 rows x 5 columns]

# %%
# Takes correlation of the residuals, takes absolute value less than one
# and multiplies these values by one. Fills null values with ones and 
# rounds to two decimals.
residuals.corr()[residuals.corr().abs() < 1].mul(-1).fillna(1).round(2)
# Out:
#       P     Q     X     Y     Z
# P  1.00  0.01 -0.59  0.64  0.71
# Q  0.01  1.00  0.50 -0.14 -0.01
# X -0.59  0.50  1.00  0.75  0.83
# Y  0.64 -0.14  0.75  1.00 -0.90
# Z  0.71 -0.01  0.83 -0.90  1.00

# %%
# !pip install pingouin
# Has a pandas dataframe extension
import pingouin
df.pcorr().round(2)
# Out:
#       P     Q     X     Y     Z
# P  1.00  0.01 -0.59  0.64  0.71
# Q  0.01  1.00  0.50 -0.14 -0.01
# X -0.59  0.50  1.00  0.75  0.83
# Y  0.64 -0.14  0.75  1.00 -0.90
# Z  0.71 -0.01  0.83 -0.90  1.00

# %%
from datlib.plots import *
corr_matrix_heatmap(df.corr(), 
                    save_fig = False, 
                    pp = None)

# %%
corr_matrix_heatmap(df.pcorr(),
                   save_fig = False,
                   pp = None)

# %%
pcorr_pvalues = {}

# y = name, Y = data
for y, Y in residuals.items():
    pcorr_pvalues[y] = {}
    for x, X in residuals.items():
        if x != y:
            # Regress one residual on the other, save the p value for the 
            # explanatory variable. This is the p value of the partial
            # correlation
            results = sm.OLS(Y, X).fit()
            pcorr_pvalues[y][x] = results.pvalues[x]
            print(results.summary())
        else:
            pcorr_pvalues[y][x] = np.NaN
            
pd.DataFrame(pcorr_pvalues).round(2)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      P   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.4973
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                       0.481
# Time:                        18:05:08   Log-Likelihood:                         -19856.
# No. Observations:               10000   AIC:                                  3.971e+04
# Df Residuals:                    9999   BIC:                                  3.972e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Q             -0.0083      0.012     -0.705      0.481      -0.031       0.015
# ==============================================================================
# Omnibus:                        0.691   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.708   Jarque-Bera (JB):                0.723
# Skew:                          -0.013   Prob(JB):                        0.697
# Kurtosis:                       2.967   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      P   R-squared (uncentered):                   0.353
# Model:                            OLS   Adj. R-squared (uncentered):              0.353
# Method:                 Least Squares   F-statistic:                              5445.
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:08   Log-Likelihood:                         -17683.
# No. Observations:               10000   AIC:                                  3.537e+04
# Df Residuals:                    9999   BIC:                                  3.537e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X              0.3795      0.005     73.793      0.000       0.369       0.390
# ==============================================================================
# Omnibus:                        0.973   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.615   Jarque-Bera (JB):                1.002
# Skew:                          -0.013   Prob(JB):                        0.606
# Kurtosis:                       2.958   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      P   R-squared (uncentered):                   0.412
# Model:                            OLS   Adj. R-squared (uncentered):              0.412
# Method:                 Least Squares   F-statistic:                              7015.
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:08   Log-Likelihood:                         -17199.
# No. Observations:               10000   AIC:                                  3.440e+04
# Df Residuals:                    9999   BIC:                                  3.441e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Y             -0.5123      0.006    -83.753      0.000      -0.524      -0.500
# ==============================================================================
# Omnibus:                        1.640   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.440   Jarque-Bera (JB):                1.626
# Skew:                          -0.031   Prob(JB):                        0.444
# Kurtosis:                       3.008   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      P   R-squared (uncentered):                   0.508
# Model:                            OLS   Adj. R-squared (uncentered):              0.508
# Method:                 Least Squares   F-statistic:                          1.031e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -16313.
# No. Observations:               10000   AIC:                                  3.263e+04
# Df Residuals:                    9999   BIC:                                  3.263e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Z             -0.2526      0.002   -101.551      0.000      -0.257      -0.248
# ==============================================================================
# Omnibus:                        1.587   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.452   Jarque-Bera (JB):                1.549
# Skew:                          -0.024   Prob(JB):                        0.461
# Kurtosis:                       3.038   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Q   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.4973
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                       0.481
# Time:                        18:05:09   Log-Likelihood:                         -18243.
# No. Observations:               10000   AIC:                                  3.649e+04
# Df Residuals:                    9999   BIC:                                  3.650e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P             -0.0060      0.009     -0.705      0.481      -0.023       0.011
# ==============================================================================
# Omnibus:                        2.260   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.323   Jarque-Bera (JB):                2.262
# Skew:                          -0.037   Prob(JB):                        0.323
# Kurtosis:                       2.996   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Q   R-squared (uncentered):                   0.254
# Model:                            OLS   Adj. R-squared (uncentered):              0.254
# Method:                 Least Squares   F-statistic:                              3401.
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -16780.
# No. Observations:               10000   AIC:                                  3.356e+04
# Df Residuals:                    9999   BIC:                                  3.357e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X             -0.2740      0.005    -58.320      0.000      -0.283      -0.265
# ==============================================================================
# Omnibus:                        0.884   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.643   Jarque-Bera (JB):                0.916
# Skew:                          -0.018   Prob(JB):                        0.633
# Kurtosis:                       2.970   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Q   R-squared (uncentered):                   0.019
# Model:                            OLS   Adj. R-squared (uncentered):              0.019
# Method:                 Least Squares   F-statistic:                              198.3
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                    1.33e-44
# Time:                        18:05:09   Log-Likelihood:                         -18145.
# No. Observations:               10000   AIC:                                  3.629e+04
# Df Residuals:                    9999   BIC:                                  3.630e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Y              0.0947      0.007     14.081      0.000       0.081       0.108
# ==============================================================================
# Omnibus:                        1.696   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.428   Jarque-Bera (JB):                1.704
# Skew:                          -0.032   Prob(JB):                        0.427
# Kurtosis:                       2.992   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Q   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.3724
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                       0.542
# Time:                        18:05:09   Log-Likelihood:                         -18243.
# No. Observations:               10000   AIC:                                  3.649e+04
# Df Residuals:                    9999   BIC:                                  3.650e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Z              0.0018      0.003      0.610      0.542      -0.004       0.008
# ==============================================================================
# Omnibus:                        2.256   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.324   Jarque-Bera (JB):                2.259
# Skew:                          -0.037   Prob(JB):                        0.323
# Kurtosis:                       2.996   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      X   R-squared (uncentered):                   0.353
# Model:                            OLS   Adj. R-squared (uncentered):              0.353
# Method:                 Least Squares   F-statistic:                              5445.
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -22160.
# No. Observations:               10000   AIC:                                  4.432e+04
# Df Residuals:                    9999   BIC:                                  4.433e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P              0.9291      0.013     73.793      0.000       0.904       0.954
# ==============================================================================
# Omnibus:                        0.245   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.885   Jarque-Bera (JB):                0.275
# Skew:                          -0.004   Prob(JB):                        0.872
# Kurtosis:                       2.975   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      X   R-squared (uncentered):                   0.254
# Model:                            OLS   Adj. R-squared (uncentered):              0.254
# Method:                 Least Squares   F-statistic:                              3401.
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -22870.
# No. Observations:               10000   AIC:                                  4.574e+04
# Df Residuals:                    9999   BIC:                                  4.575e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Q             -0.9263      0.016    -58.320      0.000      -0.957      -0.895
# ==============================================================================
# Omnibus:                        0.369   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.832   Jarque-Bera (JB):                0.399
# Skew:                          -0.008   Prob(JB):                        0.819
# Kurtosis:                       2.974   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      X   R-squared (uncentered):                   0.560
# Model:                            OLS   Adj. R-squared (uncentered):              0.560
# Method:                 Least Squares   F-statistic:                          1.274e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -20225.
# No. Observations:               10000   AIC:                                  4.045e+04
# Df Residuals:                    9999   BIC:                                  4.046e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Y             -0.9344      0.008   -112.872      0.000      -0.951      -0.918
# ==============================================================================
# Omnibus:                        0.359   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.836   Jarque-Bera (JB):                0.369
# Skew:                          -0.014   Prob(JB):                        0.832
# Kurtosis:                       2.992   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      X   R-squared (uncentered):                   0.696
# Model:                            OLS   Adj. R-squared (uncentered):              0.696
# Method:                 Least Squares   F-statistic:                          2.291e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -18377.
# No. Observations:               10000   AIC:                                  3.676e+04
# Df Residuals:                    9999   BIC:                                  3.676e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Z             -0.4628      0.003   -151.362      0.000      -0.469      -0.457
# ==============================================================================
# Omnibus:                        0.122   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.941   Jarque-Bera (JB):                0.142
# Skew:                           0.005   Prob(JB):                        0.931
# Kurtosis:                       2.984   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Y   R-squared (uncentered):                   0.412
# Model:                            OLS   Adj. R-squared (uncentered):              0.412
# Method:                 Least Squares   F-statistic:                              7015.
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -19458.
# No. Observations:               10000   AIC:                                  3.892e+04
# Df Residuals:                    9999   BIC:                                  3.892e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P             -0.8048      0.010    -83.753      0.000      -0.824      -0.786
# ==============================================================================
# Omnibus:                        0.743   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.690   Jarque-Bera (JB):                0.707
# Skew:                           0.014   Prob(JB):                        0.702
# Kurtosis:                       3.031   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Y   R-squared (uncentered):                   0.019
# Model:                            OLS   Adj. R-squared (uncentered):              0.019
# Method:                 Least Squares   F-statistic:                              198.3
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                    1.33e-44
# Time:                        18:05:09   Log-Likelihood:                         -22017.
# No. Observations:               10000   AIC:                                  4.404e+04
# Df Residuals:                    9999   BIC:                                  4.404e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Q              0.2054      0.015     14.081      0.000       0.177       0.234
# ==============================================================================
# Omnibus:                        0.568   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.753   Jarque-Bera (JB):                0.586
# Skew:                           0.017   Prob(JB):                        0.746
# Kurtosis:                       2.986   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Y   R-squared (uncentered):                   0.560
# Model:                            OLS   Adj. R-squared (uncentered):              0.560
# Method:                 Least Squares   F-statistic:                          1.274e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -18007.
# No. Observations:               10000   AIC:                                  3.602e+04
# Df Residuals:                    9999   BIC:                                  3.602e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X             -0.5996      0.005   -112.872      0.000      -0.610      -0.589
# ==============================================================================
# Omnibus:                        0.426   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.808   Jarque-Bera (JB):                0.457
# Skew:                           0.009   Prob(JB):                        0.796
# Kurtosis:                       2.973   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Y   R-squared (uncentered):                   0.803
# Model:                            OLS   Adj. R-squared (uncentered):              0.803
# Method:                 Least Squares   F-statistic:                          4.087e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -13982.
# No. Observations:               10000   AIC:                                  2.797e+04
# Df Residuals:                    9999   BIC:                                  2.797e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Z              0.3983      0.002    202.152      0.000       0.394       0.402
# ==============================================================================
# Omnibus:                        0.312   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.856   Jarque-Bera (JB):                0.343
# Skew:                           0.001   Prob(JB):                        0.842
# Kurtosis:                       2.971   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Z   R-squared (uncentered):                   0.508
# Model:                            OLS   Adj. R-squared (uncentered):              0.508
# Method:                 Least Squares   F-statistic:                          1.031e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -26684.
# No. Observations:               10000   AIC:                                  5.337e+04
# Df Residuals:                    9999   BIC:                                  5.338e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P             -2.0101      0.020   -101.551      0.000      -2.049      -1.971
# ==============================================================================
# Omnibus:                        6.626   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                7.284
# Skew:                          -0.005   Prob(JB):                       0.0262
# Kurtosis:                       3.132   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Z   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.3724
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                       0.542
# Time:                        18:05:09   Log-Likelihood:                         -30227.
# No. Observations:               10000   AIC:                                  6.046e+04
# Df Residuals:                    9999   BIC:                                  6.046e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Q              0.0202      0.033      0.610      0.542      -0.045       0.085
# ==============================================================================
# Omnibus:                        0.328   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.849   Jarque-Bera (JB):                0.358
# Skew:                           0.007   Prob(JB):                        0.836
# Kurtosis:                       2.974   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Z   R-squared (uncentered):                   0.696
# Model:                            OLS   Adj. R-squared (uncentered):              0.696
# Method:                 Least Squares   F-statistic:                          2.291e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -24271.
# No. Observations:               10000   AIC:                                  4.854e+04
# Df Residuals:                    9999   BIC:                                  4.855e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X             -1.5043      0.010   -151.362      0.000      -1.524      -1.485
# ==============================================================================
# Omnibus:                        2.660   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.265   Jarque-Bera (JB):                2.564
# Skew:                          -0.005   Prob(JB):                        0.277
# Kurtosis:                       2.922   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Z   R-squared (uncentered):                   0.803
# Model:                            OLS   Adj. R-squared (uncentered):              0.803
# Method:                 Least Squares   F-statistic:                          4.087e+04
# Date:                Mon, 01 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -22094.
# No. Observations:               10000   AIC:                                  4.419e+04
# Df Residuals:                    9999   BIC:                                  4.420e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Y              2.0173      0.010    202.152      0.000       1.998       2.037
# ==============================================================================
# Omnibus:                        0.813   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.666   Jarque-Bera (JB):                0.776
# Skew:                           0.014   Prob(JB):                        0.678
# Kurtosis:                       3.033   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#       P     Q    X    Y     Z
# P   NaN  0.48  0.0  0.0  0.00
# Q  0.48   NaN  0.0  0.0  0.54
# X  0.00  0.00  NaN  0.0  0.00
# Y  0.00  0.00  0.0  NaN  0.00
# Z  0.00  0.54  0.0  0.0   NaN

# %% [markdown]
# ## Using Partial Correlations to Build a Causal Skeleton

# %%
undirected_graph = {key:[] for key in df.keys()}
for x in undirected_graph:
    undirected_graph[x] = [y for y in df.keys() if y != x]
        
undirected_graph
# Out:
# {'P': ['Q', 'X', 'Y', 'Z'],
#  'Q': ['P', 'X', 'Y', 'Z'],
#  'X': ['P', 'Q', 'Y', 'Z'],
#  'Y': ['P', 'Q', 'X', 'Z'],
#  'Z': ['P', 'Q', 'X', 'Y']}

# %%
import copy

# Removes the links from P because there are no connections for P besides Z
p_val = 0.01
def build_skeleton(df, undirected_graph):
    def check_remaining_controls(control_vars, 
                                 undirected_graph, 
                                 x, 
                                 y, 
                                 controls_used):
        for c_var in control_vars:
            # Sets c_used every time use cycle through new control
            # Program will iterate through remaining controls
            # Until the statistical significance is broken
            c_used = copy.copy(controls_used)
            if y in undirected_graph[x]:
                c_used.append(c_var)
                print(x, y, controls_used)
                test = df.partial_corr(x = x,
                                       y = y, 
                                       covar = c_used,
                                       method = "pearson")
                if test["p-val"].values[0] > p_val:
                    undirected_graph[x].remove(y)
                    break
                else:
                    remaining_controls = copy.copy(control_vars)
                    remaining_controls.remove(c_var)
                    # Recursive function that iterates through remaining variables
                    check_remaining_controls(remaining_controls,
                                             undirected_graph,
                                             x,
                                             y,
                                             c_used)
    for x in df.keys():
        ys = undirected_graph[x]
        for y in df.keys():
            if x != y:
                test = df.partial_corr(x = x,
                                       y = y,
                                       covar = None,
                                       method = "pearson")
                if test["p-val"].values[0] > p_val:
                    undirected_graph[x].remove(y)
                else:
                    control_vars = [z for z in df.keys() if z != y and z != x]
                    check_remaining_controls(control_vars,
                                             undirected_graph,
                                             x, 
                                             y,
                                             [])
    return undirected_graph

build_skeleton(df, undirected_graph)
# Out:
# P Z []
# P Z ['Q']
# P Z ['Q', 'X']
# P Z ['Q']
# P Z ['Q', 'Y']
# P Z []
# P Z ['X']
# P Z ['X', 'Q']
# P Z ['X']
# P Z ['X', 'Y']
# P Z []
# P Z ['Y']
# P Z ['Y', 'Q']
# P Z ['Y']
# P Z ['Y', 'X']
# Q X []
# Q X ['P']
# Q X ['P', 'Y']
# Q X ['P']
# Q X ['P', 'Z']
# Q X []
# Q X ['Y']
# Q X ['Y', 'P']
# Q X ['Y']
# Q X ['Y', 'Z']
# Q X []
# Q X ['Z']
# Q X ['Z', 'P']
# Q X ['Z']
# Q X ['Z', 'Y']
# Q Y []
# Q Y ['P']
# Q Y ['P', 'X']
# Q Y ['P']
# Q Y ['P', 'Z']
# Q Y []
# Q Y ['X']
# Q Y ['X', 'P']
# Q Y ['X']
# Q Y ['X', 'Z']
# Q Y []
# Q Y ['Z']
# Q Y ['Z', 'P']
# Q Y ['Z']
# Q Y ['Z', 'X']
# Q Z []
# Q Z ['P']
# Q Z ['P', 'X']
# X Q []
# X Q ['P']
# X Q ['P', 'Y']
# X Q ['P']
# X Q ['P', 'Z']
# X Q []
# X Q ['Y']
# X Q ['Y', 'P']
# X Q ['Y']
# X Q ['Y', 'Z']
# X Q []
# X Q ['Z']
# X Q ['Z', 'P']
# X Q ['Z']
# X Q ['Z', 'Y']
# X Y []
# X Y ['P']
# X Z []
# X Z ['P']
# X Z ['P', 'Q']
# X Z ['P']
# X Z ['P', 'Y']
# X Z []
# X Z ['Q']
# X Z ['Q', 'P']
# X Z ['Q']
# X Z ['Q', 'Y']
# X Z []
# X Z ['Y']
# X Z ['Y', 'P']
# X Z ['Y']
# X Z ['Y', 'Q']
# Y Q []
# Y Q ['P']
# Y Q ['P', 'X']
# Y Q ['P']
# Y Q ['P', 'Z']
# Y Q []
# Y Q ['X']
# Y Q ['X', 'P']
# Y Q ['X']
# Y Q ['X', 'Z']
# Y Q []
# Y Q ['Z']
# Y Q ['Z', 'P']
# Y Q ['Z']
# Y Q ['Z', 'X']
# Y X []
# Y X ['P']
# Y Z []
# Y Z ['P']
# Y Z ['P', 'Q']
# Y Z ['P']
# Y Z ['P', 'X']
# Y Z []
# Y Z ['Q']
# Y Z ['Q', 'P']
# Y Z ['Q']
# Y Z ['Q', 'X']
# Y Z []
# Y Z ['X']
# Y Z ['X', 'P']
# Y Z ['X']
# Y Z ['X', 'Q']
# Z P []
# Z P ['Q']
# Z P ['Q', 'X']
# Z P ['Q']
# Z P ['Q', 'Y']
# Z P []
# Z P ['X']
# Z P ['X', 'Q']
# Z P ['X']
# Z P ['X', 'Y']
# Z P []
# Z P ['Y']
# Z P ['Y', 'Q']
# Z P ['Y']
# Z P ['Y', 'X']
# Z Q []
# Z Q ['P']
# Z Q ['P', 'X']
# Z X []
# Z X ['P']
# Z X ['P', 'Q']
# Z X ['P']
# Z X ['P', 'Y']
# Z X []
# Z X ['Q']
# Z X ['Q', 'P']
# Z X ['Q']
# Z X ['Q', 'Y']
# Z X []
# Z X ['Y']
# Z X ['Y', 'P']
# Z X ['Y']
# Z X ['Y', 'Q']
# Z Y []
# Z Y ['P']
# Z Y ['P', 'Q']
# Z Y ['P']
# Z Y ['P', 'X']
# Z Y []
# Z Y ['Q']
# Z Y ['Q', 'P']
# Z Y ['Q']
# Z Y ['Q', 'X']
# Z Y []
# Z Y ['X']
# Z Y ['X', 'P']
# Z Y ['X']
# Z Y ['X', 'Q']
# {'P': ['Z'],
#  'Q': ['X', 'Y'],
#  'X': ['Q', 'Z'],
#  'Y': ['Q', 'Z'],
#  'Z': ['P', 'X', 'Y']}

# %% [markdown]
# ## Graphing the Skeleton

# %%
import matplotlib.pyplot as plt
import networkx as nx

def graph_DAG(undirected_graph, 
              df, 
              title = "DAG Structure"):
    pcorr_matrix = df.pcorr()
    graph = nx.Graph()
    edges = []
    edge_labels = {}
    for key in undirected_graph:
        # Refers to the first key that there is a correlation with
        for key2 in undirected_graph[key]:
            if (key2, key) not in edges:
                edge = (key, key2)
                edges.append(edge)
                edge_labels[edge] = str(round(pcorr_matrix.loc[key][key2], 2))
                
    print(edges)
    print(edge_labels)
    
    graph.add_edges_from(edges)

graph_DAG(undirected_graph, df)
# Out:
# [('P', 'Z'), ('Q', 'X'), ('Q', 'Y'), ('X', 'Z'), ('Y', 'Z')]
# {('P', 'Z'): '0.71', ('Q', 'X'): '0.5', ('Q', 'Y'): '-0.14', ('X', 'Z'): '0.83', ('Y', 'Z'): '-0.9'}
