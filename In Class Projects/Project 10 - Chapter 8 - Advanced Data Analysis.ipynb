# %% [markdown]
# # Project 10: Chapter 8: Advanced Data Analysis

# %% [markdown]
# ## Plotting with Double Index
#
# In this example, the Fraser Economic Freedom Index's first three rows are blank. This will be corrected and the Maddison Project will be used.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_excel("mpd2018.xlsx",
                     sheet_name = "Full data",
                     # [0,2] will select countrycode as the primary index
                     # and year as the secondary index
                     index_col = [0,2])

# %%
data
# Out:
#                       country  cgdppc  rgdpnapc      pop         i_cig i_bm
# countrycode year
# AFG         1820  Afghanistan     NaN       NaN   3280.0           NaN  NaN
#             1870  Afghanistan     NaN       NaN   4207.0           NaN  NaN
#             1913  Afghanistan     NaN       NaN   5730.0           NaN  NaN
#             1950  Afghanistan  2392.0    2392.0   8150.0  Extrapolated  NaN
#             1951  Afghanistan  2422.0    2422.0   8284.0  Extrapolated  NaN
# ...                       ...     ...       ...      ...           ...  ...
# ZWE         2012     Zimbabwe  1623.0    1604.0  12620.0  Extrapolated  NaN
#             2013     Zimbabwe  1801.0    1604.0  13183.0  Extrapolated  NaN
#             2014     Zimbabwe  1797.0    1594.0  13772.0  Extrapolated  NaN
#             2015     Zimbabwe  1759.0    1560.0  14230.0  Extrapolated  NaN
#             2016     Zimbabwe  1729.0    1534.0  14547.0  Extrapolated  NaN
#
# [19873 rows x 6 columns]

# %%
data.index
# Out:
# MultiIndex([('AFG', 1820),
#             ('AFG', 1870),
#             ('AFG', 1913),
#             ('AFG', 1950),
#             ('AFG', 1951),
#             ('AFG', 1952),
#             ('AFG', 1953),
#             ('AFG', 1954),
#             ('AFG', 1955),
#             ('AFG', 1956),
#             ...
#             ('ZWE', 2007),
#             ('ZWE', 2008),
#             ('ZWE', 2009),
#             ('ZWE', 2010),
#             ('ZWE', 2011),
#             ('ZWE', 2012),
#             ('ZWE', 2013),
#             ('ZWE', 2014),
#             ('ZWE', 2015),
#             ('ZWE', 2016)],
#            names=['countrycode', 'year'], length=19873)

# %%
years = list(data.groupby("year").mean().index)
years
# Out:
# [1,
#  730,
#  1000,
#  1150,
#  1280,
#  1281,
#  1282,
#  1283,
#  1284,
#  1285,
#  1286,
#  1287,
#  1288,
#  1289,
#  1290,
#  1291,
#  1292,
#  1293,
#  1294,
#  1295,
#  1296,
#  1297,
#  1298,
#  1299,
#  1300,
#  1301,
#  1302,
#  1303,
#  1304,
#  1305,
#  1306,
#  1307,
#  1308,
#  1309,
#  1310,
#  1311,
#  1312,
#  1313,
#  1314,
#  1315,
#  1316,
#  1317,
#  1318,
#  1319,
#  1320,
#  1321,
#  1322,
#  1323,
#  1324,
#  1325,
#  1326,
#  1327,
#  1328,
#  1329,
#  1330,
#  1331,
#  1332,
#  1333,
#  1334,
#  1335,
#  1336,
#  1337,
#  1338,
#  1339,
#  1340,
#  1341,
#  1342,
#  1343,
#  1344,
#  1345,
#  1346,
#  1347,
#  1348,
#  1349,
#  1350,
#  1351,
#  1352,
#  1353,
#  1354,
#  1355,
#  1356,
#  1357,
#  1358,
#  1359,
#  1360,
#  1361,
#  1362,
#  1363,
#  1364,
#  1365,
#  1366,
#  1367,
#  1368,
#  1369,
#  1370,
#  1371,
#  1372,
#  1373,
#  1374,
#  1375,
#  1376,
#  1377,
#  1378,
#  1379,
#  1380,
#  1381,
#  1382,
#  1383,
#  1384,
#  1385,
#  1386,
# ...

# %%
countries = list(data.groupby("countrycode").mean().index)
countries
# Out:
# ['AFG',
#  'AGO',
#  'ALB',
#  'ARE',
#  'ARG',
#  'ARM',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BFA',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BIH',
#  'BLR',
#  'BOL',
#  'BRA',
#  'BRB',
#  'BWA',
#  'CAF',
#  'CAN',
#  'CHE',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COL',
#  'COM',
#  'CPV',
#  'CRI',
#  'CSK',
#  'CUB',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DJI',
#  'DMA',
#  'DNK',
#  'DOM',
#  'DZA',
#  'ECU',
#  'EGY',
#  'ESP',
#  'EST',
#  'ETH',
#  'FIN',
#  'FRA',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GHA',
#  'GIN',
#  'GMB',
#  'GNB',
#  'GNQ',
#  'GRC',
#  'GTM',
#  'HKG',
#  'HND',
#  'HRV',
#  'HTI',
#  'HUN',
#  'IDN',
#  'IND',
#  'IRL',
#  'IRN',
#  'IRQ',
#  'ISL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JOR',
#  'JPN',
#  'KAZ',
#  'KEN',
#  'KGZ',
#  'KHM',
#  'KOR',
#  'KWT',
#  'LAO',
#  'LBN',
#  'LBR',
#  'LBY',
#  'LCA',
#  'LKA',
#  'LSO',
#  'LTU',
#  'LUX',
#  'LVA',
#  'MAR',
#  'MDA',
#  'MDG',
#  'MEX',
#  'MKD',
#  'MLI',
# ...

# %% [markdown]
# ## Plotting Data by Country

# %%
# Creates list of tuples
pairs = [("CAN", "FIN"), ("FRA", "DEU"), ("USA", "GBR", "ESP", "MEX")]
# Assigns each country in each grouping a certain line style. First = -
# second = :, etc
linestyles = ["-", ":", "--", "-."]

# %%
# Creates a figure for each grouping of countries
plt.rcParams.update({"legend.fontsize": 25, "legend.handlelength": 2})  
plt.rcParams.update({"font.size": 25})
for pair in pairs:
    fig, ax = plt.subplots(figsize = (16,8))
    for i in range(len(pair)):
        country = pair[i]
        linestyle = linestyles[i]
        data.loc[country,:]["cgdppc"].dropna().plot.line(ax = ax,
                                                         label = country,
                                                         linestyle = linestyle)
    # Causes the graph to start at 1825 because not much data before
    plt.xlim([1825, max(years)])
    # $ before and after each word makes words look different
    # Need \$ so graph knows an actual $ is wanted
    plt.ylabel("$Real$ $GDP$ $Per$ $Capita$\n2011 \$ U.S.",
              fontsize = 30)
    plt.legend()

# %% [markdown]
# ## Merging Data Sets with Double Index

# %%
fraser_data = pd.read_csv("cleanedEconFreedomData.csv",
                          index_col = [0, 1],
                          # Wanted dates imported in the same format
                          # This is done by turning off parse_dates
                          parse_dates = False)
# Drops all blank columns and rows
# thresh = 1 is the same as how = "all"
fraser_data = fraser_data.dropna(axis = 0,
                                 thresh = 1).dropna(axis = 1,
                                                    thresh = 1)
fraser_data
# Out:
#                     EFW  Size Of Government  Legal System & Property Rights  \
# ISO_Code Year
# ALB      2017  7.673511            7.528167                        5.064907
#          2016  7.637742            7.875862                        5.071814
#          2015  7.639666            7.904257                        5.003489
#          2014  7.586769            7.882037                        4.666740
#          2013  7.389525            7.807904                        4.543782
# ...                 ...                 ...                             ...
# ZWE      2000  4.299839            5.365058                        4.662445
#          1995  5.518614            6.418859                        5.138131
#          1990  4.516140            5.108843                        3.439437
#          1985  4.226841            5.026250                        2.633492
#          1980  4.054740            6.322625                        1.379602
#
# ...

# %%
# Renames data so it is easier to remember
maddison_data = data
# Adds RGDP Per Capita column to fraser from maddison
fraser_data["RGDP Per Capita"] = maddison_data["rgdpnapc"]
fraser_data
# Out:
#                     EFW  Size Of Government  Legal System & Property Rights  \
# ISO_Code Year
# ALB      2017  7.673511            7.528167                        5.064907
#          2016  7.637742            7.875862                        5.071814
#          2015  7.639666            7.904257                        5.003489
#          2014  7.586769            7.882037                        4.666740
#          2013  7.389525            7.807904                        4.543782
# ...                 ...                 ...                             ...
# ZWE      2000  4.299839            5.365058                        4.662445
#          1995  5.518614            6.418859                        5.138131
#          1990  4.516140            5.108843                        3.439437
#          1985  4.226841            5.026250                        2.633492
#          1980  4.054740            6.322625                        1.379602
#
# ...

# %%
fraser_data.to_csv("fraserDataWithRGDPPC.csv")

# %% [markdown]
# ## Creating Indicator Variables

# %%
def create_indicator_variable(data,
                              indicator_name,
                              index_name,
                              target_index_list):
    # Prepare column with name of the indicator variable
    data[indicator_name] = 0
    # For each index's name that matches an entry in target_index_list,
    # value of 1 will be recorded
    # for index in target_index_list:
        # .loc checks row entries to see if entity index matches
        # the entity from the target index list
        # Sets values of indicator_name (column) to 1
        # for all such rows 
    data.loc[target_index_list, [indicator_name]] = int(1)

data = pd.read_csv("fraserDataWithRGDPPC.csv",
                   index_col = ["ISO_Code", "Year"],
                   parse_dates = True)

# Select ISO_Code from names of double index
index_name = data.index.names[0]
indicator_name = "North America"
countries_in_north_america = [
    "BHS", "BLZ", "CAN", "CRI", "DOM", "SLV",
    "GTM", "HTI", "HND", "JAM", "MEX", "NIC", "PAN",
    "TTO", "USA"]
create_indicator_variable(data = data,
                          indicator_name = indicator_name,
                          index_name = index_name,
                          target_index_list = countries_in_north_america)

# %%
# Checks to see if USA is in NA
# Could also replace USA with countries_in_north_america
# This would check all the countries in NA and put a 1 for them
data.loc["USA", ["North America"]]
# Out:
#             North America
# Year
# 2017-01-01              1
# 2016-01-01              1
# 2015-01-01              1
# 2014-01-01              1
# 2013-01-01              1
# 2012-01-01              1
# 2011-01-01              1
# 2010-01-01              1
# 2009-01-01              1
# 2008-01-01              1
# 2007-01-01              1
# 2006-01-01              1
# 2005-01-01              1
# 2004-01-01              1
# 2003-01-01              1
# 2002-01-01              1
# 2001-01-01              1
# 2000-01-01              1
# 1995-01-01              1
# 1990-01-01              1
# 1985-01-01              1
# 1980-01-01              1
# 1975-01-01              1
# 1970-01-01              1

# %%
# Shows each country in NA labeled as a 1
data[["North America"]]
# Out:
#                      North America
# ISO_Code Year
# ALB      2017-01-01              0
#          2016-01-01              0
#          2015-01-01              0
#          2014-01-01              0
#          2013-01-01              0
# ...                            ...
# ZWE      2000-01-01              0
#          1995-01-01              0
#          1990-01-01              0
#          1985-01-01              0
#          1980-01-01              0
#
# [3030 rows x 1 columns]

# %%
from matplotlib import cm
year = 2000

# Makes sure there are only two colors on the graph
norm = cm.colors.Normalize()
# Change the 2 to a different number if different color ranges are wanted
# Ex: set to 10 makes 10 different color segments
cmap = cm.get_cmap('coolwarm', 2)
plt.cm.ScalarMappable(cmap = cmap,
                      norm = norm)

plot_data = data[data.index.get_level_values("Year") == str(year)]
fig, ax = plt.subplots(figsize = (24, 16))
plot_data.plot.scatter(x = "EFW",
                       y = "RGDP Per Capita",
                       c = "North America",
                       cmap = cmap,
                       norm = norm,
                       ax = ax,
                       s = 50)
ax.set_title(str(year), fontsize = 50)
# Out:
# Text(0.5, 1.0, '2000')

# %% [markdown]
# ## Creating a Quantile Ranking

# %%
# Number of divisions
n = 5
# Creates a column identifying n-tile rank
quantile_var = "RGDP Per Capita"
quantile_name = quantile_var + " " + str(n) + "-tile"
data[quantile_name] = np.nan
data
# Out:
#                           EFW  Size Of Government  \
# ISO_Code Year
# ALB      2017-01-01  7.673511            7.528167
#          2016-01-01  7.637742            7.875862
#          2015-01-01  7.639666            7.904257
#          2014-01-01  7.586769            7.882037
#          2013-01-01  7.389525            7.807904
# ...                       ...                 ...
# ZWE      2000-01-01  4.299839            5.365058
#          1995-01-01  5.518614            6.418859
#          1990-01-01  4.516140            5.108843
#          1985-01-01  4.226841            5.026250
#          1980-01-01  4.054740            6.322625
#
#                      Legal System & Property Rights  Sound Money  \
# ISO_Code Year
# ALB      2017-01-01                        5.064907     9.648271
#          2016-01-01                        5.071814     9.553657
#          2015-01-01                        5.003489     9.585625
#          2014-01-01                        4.666740     9.629320
# ...

# %%
def create_quantile(n, 
                    data, 
                    year, 
                    quantile_var, 
                    quantile_name):
    # Identifies countries for a given year
    year_index = data.index.get_level_values("Year") == year
    # Selects the subset of the dataframe by year and variable
    year_data = data[year_index][quantile_var]
    # Creates a dictionary that holds the quantile values
    quantile_values_dict = {i:year_data.quantile(i/n) for i in range(1, n + 1)}
    
    # Cycles through each country for the year
    for index in data[year_index].index:
        # Identifies the value of the variable
        val = data.loc[index][quantile_var]
        # Compares the value to the values that divide each quantile
        for i in range(1, n + 1):
            # Saves the quantile as i if the value is < highest in the quantile
            if val <= quantile_values_dict[i]:
                data.loc[index,[quantile_name]] = int((n + 1) - i)
                break
            # Otherwise checks the highest value of the next quantile
            else:
                continue
                
years = data.groupby("Year").mean().index
for year in years:
    create_quantile(n, 
                    data, 
                    year, 
                    quantile_var, 
                    quantile_name)

# %%
# Calls RGDP Per Capita with the quantile rankings
data[["RGDP Per Capita", "RGDP Per Capita 5-tile"]]
# Out:
#                      RGDP Per Capita  RGDP Per Capita 5-tile
# ISO_Code Year
# ALB      2017-01-01              NaN                     NaN
#          2016-01-01          10342.0                     3.0
#          2015-01-01          10032.0                     3.0
#          2014-01-01           9808.0                     3.0
#          2013-01-01           9660.0                     3.0
# ...                              ...                     ...
# ZWE      2000-01-01           2249.0                     5.0
#          1995-01-01           2156.0                     5.0
#          1990-01-01           2232.0                     5.0
#          1985-01-01           2198.0                     5.0
#          1980-01-01           2133.0                     5.0
#
# [3030 rows x 2 columns]

# %%
# Calls specific country
# Can call multiple countries at once
data.loc["USA", "RGDP Per Capita 5-tile"]
# Out:
# Year
# 2017-01-01    NaN
# 2016-01-01    1.0
# 2015-01-01    1.0
# 2014-01-01    1.0
# 2013-01-01    1.0
# 2012-01-01    1.0
# 2011-01-01    1.0
# 2010-01-01    1.0
# 2009-01-01    1.0
# 2008-01-01    1.0
# 2007-01-01    1.0
# 2006-01-01    1.0
# 2005-01-01    1.0
# 2004-01-01    1.0
# 2003-01-01    1.0
# 2002-01-01    1.0
# 2001-01-01    1.0
# 2000-01-01    1.0
# 1995-01-01    1.0
# 1990-01-01    1.0
# 1985-01-01    1.0
# 1980-01-01    1.0
# 1975-01-01    1.0
# 1970-01-01    1.0
# Name: RGDP Per Capita 5-tile, dtype: float64

# %%
# Creates a graph of certain countries to compare them
# 1 is best: better to flip the axis
fig, ax = plt.subplots(figsize = (14, 8))
for country in ["USA", "DEU", "GBR", "CAN", "FRA"]:
    data.loc[country, "RGDP Per Capita " + str(n) + "-tile"].plot.line(ax = ax,
                                                         label = country)
plt.legend()

# %%
# Compares countries by specific year
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable
import datetime

year = 2016
plot_data = data[data.index.get_level_values("Year") == datetime.datetime(year,1,1)]
fig, ax = plt.subplots(figsize = (24, 16))

# Changes colors and divides color bar
norm = cm.colors.Normalize()
cmap = cm.get_cmap('jet', n)
plt.cm.ScalarMappable(cmap = cmap, 
                      norm = norm)

plot_data.plot.scatter(x = "EFW", 
                       y = "RGDP Per Capita", 
                       c = "RGDP Per Capita " + str(n) + "-tile",
                       cmap = cmap, 
                       norm = norm, 
                       ax = ax, 
                       s = 50,
                       legend = False,
                       # Changes color bar to whole numbers
                       vmin = 0.5, 
                       vmax = n + 0.5)

ax.set_title("Year: " + str(year), fontsize = 50)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1041: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   scatter = ax.scatter(
# Text(0.5, 1.0, 'Year: 2016')

# %% [markdown]
# ## Lag Variables and Differenced Log Values

# %%
# shift(-1) is used because the years aren't sorted from earliest to latest
data["RGDP Per Capita Lag"] = data.groupby(level = "ISO_Code")["RGDP Per Capita"].shift(-1)
data[data.index.get_level_values("Year") > datetime.datetime(2001,1,1,)]
# Out:
#                           EFW  Size Of Government  \
# ISO_Code Year
# ALB      2017-01-01  7.673511            7.528167
#          2016-01-01  7.637742            7.875862
#          2015-01-01  7.639666            7.904257
#          2014-01-01  7.586769            7.882037
#          2013-01-01  7.389525            7.807904
# ...                       ...                 ...
# ZWE      2006-01-01  3.012548            4.770748
#          2005-01-01  2.889240            4.291101
#          2004-01-01  3.181057            5.184469
#          2003-01-01  3.675260            5.709175
#          2002-01-01  3.625483            5.514469
#
#                      Legal System & Property Rights  Sound Money  \
# ISO_Code Year
# ALB      2017-01-01                        5.064907     9.648271
#          2016-01-01                        5.071814     9.553657
#          2015-01-01                        5.003489     9.585625
#          2014-01-01                        4.666740     9.629320
# ...
