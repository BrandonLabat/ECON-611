# %% [markdown]
# # Project 6 - Partial Correlations and Directed Acyclic Graphs

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("fraserDataWithRGDPPC.csv", 
                   index_col=[0,1],
                   parse_dates = True).dropna()
years = np.array(sorted(list(set(data.index.get_level_values("Year")))))
years = pd.date_range(years[0], years[-2], freq = "AS")
countries = sorted(list(set(data.index.get_level_values("ISO_Code"))))
index_names = list(data.index.names)
multi_index = pd.MultiIndex.from_product([countries, 
                                          years[:-1]], 
                                          names =data.index.names)
data = data.reindex(multi_index)
data
# Out:
#                           EFW  Size of Government  \
# ISO_Code Year
# AGO      1970-01-01       NaN                 NaN
#          1971-01-01       NaN                 NaN
#          1972-01-01       NaN                 NaN
#          1973-01-01       NaN                 NaN
#          1974-01-01       NaN                 NaN
# ...                       ...                 ...
# ZWE      2010-01-01  4.374917            6.514112
#          2011-01-01  4.843441            6.424630
#          2012-01-01  4.971192            6.670469
#          2013-01-01  5.246723            6.325105
#          2014-01-01  5.582478            6.433165
#
#                      Legal System & Property Rights  Sound Money  \
# ISO_Code Year
# AGO      1970-01-01                             NaN          NaN
#          1971-01-01                             NaN          NaN
#          1972-01-01                             NaN          NaN
#          1973-01-01                             NaN          NaN
#          1974-01-01                             NaN          NaN
# ...                                             ...          ...
# ZWE      2010-01-01                        3.826300     1.972000
#          2011-01-01                        3.943725     4.109198
#          2012-01-01                        4.013004     5.378742
#          2013-01-01                        3.575827     6.895530
#          2014-01-01                        3.615584     7.966798
#
#                      Freedom to trade internationally  Regulation  \
# ISO_Code Year
# AGO      1970-01-01                               NaN         NaN
#          1971-01-01                               NaN         NaN
#          1972-01-01                               NaN         NaN
#          1973-01-01                               NaN         NaN
#          1974-01-01                               NaN         NaN
# ...                                               ...         ...
# ZWE      2010-01-01                          4.907822    4.654352
#          2011-01-01                          5.366773    4.372878
#          2012-01-01                          5.132305    3.661438
#          2013-01-01                          5.589087    3.848068
#          2014-01-01                          5.909121    3.987721
#
#                      RGDP Per Capita
# ISO_Code Year
# AGO      1970-01-01              NaN
#          1971-01-01              NaN
#          1972-01-01              NaN
#          1973-01-01              NaN
#          1974-01-01              NaN
# ...                              ...
# ZWE      2010-01-01           1425.0
#          2011-01-01           1515.0
#          2012-01-01           1623.0
#          2013-01-01           1801.0
#          2014-01-01           1797.0
#
# [6840 rows x 7 columns]

# %%
keys = list(data.keys())[1:]
df = data.copy()
df["RGDP Per Capita"] = data["RGDP Per Capita"].groupby("ISO_Code").pct_change()
df = df[keys].diff()
df = df.rename(columns={key:key.replace(" ", "\n") for key in df}).dropna()
df
# Out:
#                      Size\nof\nGovernment  Legal\nSystem\n&\nProperty\nRights  \
# ISO_Code Year
# AGO      2007-01-01             -0.103686                            0.022720
#          2008-01-01              0.068152                            0.084915
#          2009-01-01              1.797574                           -0.031306
#          2010-01-01             -1.366275                            0.050092
#          2011-01-01              0.096683                           -0.087293
# ...                                   ...                                 ...
# ZWE      2010-01-01             -0.855503                            0.117071
#          2011-01-01             -0.089482                            0.117425
#          2012-01-01              0.245839                            0.069279
#          2013-01-01             -0.345364                           -0.437177
#          2014-01-01              0.108060                            0.039756
#
#                      Sound\nMoney  Freedom\nto\ntrade\ninternationally  \
# ISO_Code Year
# AGO      2007-01-01      0.392129                            -0.043488
#          2008-01-01      0.579510                            -0.427486
#          2009-01-01      0.205423                             0.123869
#          2010-01-01      0.331967                             0.377986
#          2011-01-01      0.101526                             0.020767
# ...                           ...                                  ...
# ZWE      2010-01-01      1.024500                             0.041328
#          2011-01-01      2.137198                             0.458951
#          2012-01-01      1.269544                            -0.234468
#          2013-01-01      1.516788                             0.456781
#          2014-01-01      1.071268                             0.320035
#
#                      Regulation  RGDP\nPer\nCapita
# ISO_Code Year
# AGO      2007-01-01    0.218491          -0.189072
#          2008-01-01   -0.302899           0.023073
#          2009-01-01   -0.210128          -0.363990
#          2010-01-01    0.680722           0.404526
#          2011-01-01   -0.701467           0.021466
# ...                         ...                ...
# ZWE      2010-01-01   -0.024469           0.017473
#          2011-01-01   -0.281474          -0.009077
#          2012-01-01   -0.711440           0.008129
#          2013-01-01    0.186630           0.038386
#          2014-01-01    0.139653          -0.111894
#
# [1808 rows x 6 columns]

# %% [markdown]
# ## Partial Correlation

# %%
import statsmodels.api as sm
# Takes keys - y variable
# Creates a residuals dictionary
residuals = {}
for y_var in df.keys():
    X_vars = list(df.keys())
    X_vars.remove(y_var)
    X = df[X_vars]
    X["Constant"] = 1
    y = df[[y_var]]
    model = sm.OLS(y, X)
    results = model.fit()
    print(results.summary())
    residuals[y_var] = results.resid
residuals = pd.DataFrame(residuals)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Size
# of
# Government   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.210
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):             0.0509
# Time:                        20:21:41   Log-Likelihood:                -655.96
# No. Observations:                1808   AIC:                             1324.
# Df Residuals:                    1802   BIC:                             1357.
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Legal
# System
# &
# Property
# Rights       0.0576      0.031      1.871      0.062      -0.003       0.118
# Sound
# Money                         -0.0152      0.019     -0.815      0.415      -0.052       0.021
# Freedom
# to
# trade
# internationally     0.0310      0.028      1.108      0.268      -0.024       0.086
# Regulation                           0.0510      0.029      1.743      0.081      -0.006       0.108
# RGDP
# Per
# Capita                      0.0463      0.077      0.598      0.550      -0.105       0.198
# Constant                             0.0053      0.008      0.634      0.526      -0.011       0.022
# ==============================================================================
# Omnibus:                      252.725   Durbin-Watson:                   2.165
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1587.518
# Skew:                           0.482   Prob(JB):                         0.00
# Kurtosis:                       7.488   Cond. No.                         9.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     Legal
# System
# &
# Property
# Rights   R-squared:                       0.054
# Model:                                        OLS   Adj. R-squared:                  0.051
# Method:                             Least Squares   F-statistic:                     20.50
# Date:                            Mon, 08 Nov 2021   Prob (F-statistic):           5.91e-20
# Time:                                    20:21:41   Log-Likelihood:                -169.60
# No. Observations:                            1808   AIC:                             351.2
# Df Residuals:                                1802   BIC:                             384.2
# Df Model:                                       5
# Covariance Type:                        nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Size
# of
# Government                   0.0336      0.018      1.871      0.062      -0.002       0.069
# Sound
# Money                          0.0027      0.014      0.189      0.850      -0.025       0.031
# Freedom
# to
# trade
# internationally     0.0812      0.021      3.806      0.000       0.039       0.123
# Regulation                           0.1892      0.022      8.628      0.000       0.146       0.232
# RGDP
# Per
# Capita                      0.0719      0.059      1.216      0.224      -0.044       0.188
# Constant                            -0.0020      0.006     -0.313      0.754      -0.015       0.011
# ==============================================================================
# Omnibus:                      306.935   Durbin-Watson:                   2.292
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6086.336
# Skew:                          -0.019   Prob(JB):                         0.00
# Kurtosis:                      11.988   Cond. No.                         9.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Sound
# Money   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     6.596
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):           4.30e-06
# Time:                        20:21:41   Log-Likelihood:                -1075.3
# No. Observations:                1808   AIC:                             2163.
# Df Residuals:                    1802   BIC:                             2196.
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Size
# of
# Government                  -0.0242      0.030     -0.815      0.415      -0.082       0.034
# Legal
# System
# &
# Property
# Rights       0.0073      0.039      0.189      0.850      -0.069       0.084
# Freedom
# to
# trade
# internationally     0.1919      0.035      5.478      0.000       0.123       0.261
# Regulation                           0.0377      0.037      1.022      0.307      -0.035       0.110
# RGDP
# Per
# Capita                     -0.0279      0.098     -0.286      0.775      -0.219       0.163
# Constant                             0.0531      0.010      5.077      0.000       0.033       0.074
# ==============================================================================
# Omnibus:                      450.734   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6452.468
# Skew:                           0.762   Prob(JB):                         0.00
# Kurtosis:                      12.128   Cond. No.                         9.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Freedom
# to
# trade
# internationally   R-squared:                       0.031
# Model:                                          OLS   Adj. R-squared:                  0.028
# Method:                               Least Squares   F-statistic:                     11.44
# Date:                              Mon, 08 Nov 2021   Prob (F-statistic):           6.92e-11
# Time:                                      20:21:41   Log-Likelihood:                -342.61
# No. Observations:                              1808   AIC:                             697.2
# Df Residuals:                                  1802   BIC:                             730.2
# Df Model:                                         5
# Covariance Type:                          nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Size
# of
# Government                 0.0219      0.020      1.108      0.268      -0.017       0.061
# Legal
# System
# &
# Property
# Rights     0.0983      0.026      3.806      0.000       0.048       0.149
# Sound
# Money                        0.0853      0.016      5.478      0.000       0.055       0.116
# Regulation                         0.0477      0.025      1.940      0.053      -0.001       0.096
# RGDP
# Per
# Capita                    0.0669      0.065      1.029      0.304      -0.061       0.194
# Constant                          -0.0041      0.007     -0.578      0.563      -0.018       0.010
# ==============================================================================
# Omnibus:                      500.100   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            43089.804
# Skew:                          -0.181   Prob(JB):                         0.00
# Kurtosis:                      26.914   Cond. No.                         9.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Regulation   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     17.97
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):           1.98e-17
# Time:                        20:21:41   Log-Likelihood:                -262.93
# No. Observations:                1808   AIC:                             537.9
# Df Residuals:                    1802   BIC:                             570.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Size
# of
# Government                   0.0330      0.019      1.743      0.081      -0.004       0.070
# Legal
# System
# &
# Property
# Rights       0.2097      0.024      8.628      0.000       0.162       0.257
# Sound
# Money                          0.0154      0.015      1.022      0.307      -0.014       0.045
# Freedom
# to
# trade
# internationally     0.0437      0.023      1.940      0.053      -0.000       0.088
# RGDP
# Per
# Capita                     -0.0105      0.062     -0.169      0.866      -0.133       0.112
# Constant                             0.0337      0.007      5.057      0.000       0.021       0.047
# ==============================================================================
# Omnibus:                      182.527   Durbin-Watson:                   2.244
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1299.481
# Skew:                          -0.135   Prob(JB):                    6.63e-283
# Kurtosis:                       7.144   Cond. No.                         9.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RGDP
# Per
# Capita   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.6623
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):              0.652
# Time:                        20:21:41   Log-Likelihood:                 1494.4
# No. Observations:                1808   AIC:                            -2977.
# Df Residuals:                    1802   BIC:                            -2944.
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Size
# of
# Government                   0.0043      0.007      0.598      0.550      -0.010       0.018
# Legal
# System
# &
# Property
# Rights       0.0114      0.009      1.216      0.224      -0.007       0.030
# Sound
# Money                         -0.0016      0.006     -0.286      0.775      -0.013       0.010
# Freedom
# to
# trade
# internationally     0.0088      0.009      1.029      0.304      -0.008       0.025
# Regulation                          -0.0015      0.009     -0.169      0.866      -0.019       0.016
# Constant                            -0.0089      0.003     -3.503      0.000      -0.014      -0.004
# ==============================================================================
# Omnibus:                      835.094   Durbin-Watson:                   2.574
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15563.101
# Skew:                          -1.702   Prob(JB):                         0.00
# Kurtosis:                      16.965   Cond. No.                         4.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Takes correlation of the residuals, takes absolute value less than one
# and multiplies these values by one. Fills null values with ones and 
# rounds to two decimals.
residuals.corr()[residuals.corr().abs() < 1].mul(-1).fillna(1).round(2)
# Out:
#                                      Size\nof\nGovernment  \
# Size\nof\nGovernment                                 1.00
# Legal\nSystem\n&\nProperty\nRights                   0.04
# Sound\nMoney                                        -0.02
# Freedom\nto\ntrade\ninternationally                  0.03
# Regulation                                           0.04
# RGDP\nPer\nCapita                                    0.01
#
#                                      Legal\nSystem\n&\nProperty\nRights  \
# Size\nof\nGovernment                                               0.04
# Legal\nSystem\n&\nProperty\nRights                                 1.00
# Sound\nMoney                                                       0.00
# Freedom\nto\ntrade\ninternationally                                0.09
# Regulation                                                         0.20
# RGDP\nPer\nCapita                                                  0.03
#
#                                      Sound\nMoney  \
# Size\nof\nGovernment                        -0.02
# Legal\nSystem\n&\nProperty\nRights           0.00
# Sound\nMoney                                 1.00
# Freedom\nto\ntrade\ninternationally          0.13
# Regulation                                   0.02
# RGDP\nPer\nCapita                           -0.01
#
#                                      Freedom\nto\ntrade\ninternationally  \
# Size\nof\nGovernment                                                0.03
# Legal\nSystem\n&\nProperty\nRights                                  0.09
# Sound\nMoney                                                        0.13
# Freedom\nto\ntrade\ninternationally                                 1.00
# Regulation                                                          0.05
# RGDP\nPer\nCapita                                                   0.02
#
#                                      Regulation  RGDP\nPer\nCapita
# Size\nof\nGovernment                       0.04               0.01
# Legal\nSystem\n&\nProperty\nRights         0.20               0.03
# Sound\nMoney                               0.02              -0.01
# Freedom\nto\ntrade\ninternationally        0.05               0.02
# Regulation                                 1.00              -0.00
# RGDP\nPer\nCapita                         -0.00               1.00

# %%
import pingouin
df.pcorr().round(2)
# Out:
#                                      Size\nof\nGovernment  \
# Size\nof\nGovernment                                 1.00
# Legal\nSystem\n&\nProperty\nRights                   0.04
# Sound\nMoney                                        -0.02
# Freedom\nto\ntrade\ninternationally                  0.03
# Regulation                                           0.04
# RGDP\nPer\nCapita                                    0.01
#
#                                      Legal\nSystem\n&\nProperty\nRights  \
# Size\nof\nGovernment                                               0.04
# Legal\nSystem\n&\nProperty\nRights                                 1.00
# Sound\nMoney                                                       0.00
# Freedom\nto\ntrade\ninternationally                                0.09
# Regulation                                                         0.20
# RGDP\nPer\nCapita                                                  0.03
#
#                                      Sound\nMoney  \
# Size\nof\nGovernment                        -0.02
# Legal\nSystem\n&\nProperty\nRights           0.00
# Sound\nMoney                                 1.00
# Freedom\nto\ntrade\ninternationally          0.13
# Regulation                                   0.02
# RGDP\nPer\nCapita                           -0.01
#
#                                      Freedom\nto\ntrade\ninternationally  \
# Size\nof\nGovernment                                                0.03
# Legal\nSystem\n&\nProperty\nRights                                  0.09
# Sound\nMoney                                                        0.13
# Freedom\nto\ntrade\ninternationally                                 1.00
# Regulation                                                          0.05
# RGDP\nPer\nCapita                                                   0.02
#
#                                      Regulation  RGDP\nPer\nCapita
# Size\nof\nGovernment                       0.04               0.01
# Legal\nSystem\n&\nProperty\nRights         0.20               0.03
# Sound\nMoney                               0.02              -0.01
# Freedom\nto\ntrade\ninternationally        0.05               0.02
# Regulation                                 1.00              -0.00
# RGDP\nPer\nCapita                         -0.00               1.00

# %%
pcorr_pvalues = {}

# y = name, Y = data
for y, Y in residuals.items():
    pcorr_pvalues[y] = {}
    for x, X in residuals.items():
        if x != y:
            # Regress one residual on the other, save the p value for the 
            # explanatory variable. This is the p value of the partial
            # correlation
            results = sm.OLS(Y, X).fit()
            pcorr_pvalues[y][x] = results.pvalues[x]
            print(results.summary())
        else:
            pcorr_pvalues[y][x] = np.NaN
            
pd.DataFrame(pcorr_pvalues).round(2)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Size
# of
# Government   R-squared (uncentered):                   0.002
# Model:                            OLS   Adj. R-squared (uncentered):              0.001
# Method:                 Least Squares   F-statistic:                              3.510
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                      0.0611
# Time:                        20:22:04   Log-Likelihood:                         -654.21
# No. Observations:                1808   AIC:                                      1310.
# Df Residuals:                    1807   BIC:                                      1316.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Legal
# System
# &
# Property
# Rights    -0.0576      0.031     -1.874      0.061      -0.118       0.003
# ==============================================================================
# Omnibus:                      254.925   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1597.053
# Skew:                           0.490   Prob(JB):                         0.00
# Kurtosis:                       7.499   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Size
# of
# Government   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.6664
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.414
# Time:                        20:22:04   Log-Likelihood:                         -655.63
# No. Observations:                1808   AIC:                                      1313.
# Df Residuals:                    1807   BIC:                                      1319.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Sound
# Money     0.0152      0.019      0.816      0.414      -0.021       0.052
# ==============================================================================
# Omnibus:                      253.792   Durbin-Watson:                   2.167
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1602.153
# Skew:                           0.483   Prob(JB):                         0.00
# Kurtosis:                       7.509   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Size
# of
# Government   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              1.230
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.267
# Time:                        20:22:04   Log-Likelihood:                         -655.35
# No. Observations:                1808   AIC:                                      1313.
# Df Residuals:                    1807   BIC:                                      1318.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Freedom
# to
# trade
# internationally    -0.0310      0.028     -1.109      0.267      -0.086       0.024
# ==============================================================================
# Omnibus:                      256.404   Durbin-Watson:                   2.167
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1630.439
# Skew:                           0.489   Prob(JB):                         0.00
# Kurtosis:                       7.548   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Size
# of
# Government   R-squared (uncentered):                   0.002
# Model:                            OLS   Adj. R-squared (uncentered):              0.001
# Method:                 Least Squares   F-statistic:                              3.048
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                      0.0810
# Time:                        20:22:04   Log-Likelihood:                         -654.44
# No. Observations:                1808   AIC:                                      1311.
# Df Residuals:                    1807   BIC:                                      1316.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Regulation    -0.0510      0.029     -1.746      0.081      -0.108       0.006
# ==============================================================================
# Omnibus:                      253.235   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1608.064
# Skew:                           0.480   Prob(JB):                         0.00
# Kurtosis:                       7.519   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Size
# of
# Government   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.3591
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.549
# Time:                        20:22:04   Log-Likelihood:                         -655.78
# No. Observations:                1808   AIC:                                      1314.
# Df Residuals:                    1807   BIC:                                      1319.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RGDP
# Per
# Capita    -0.0463      0.077     -0.599      0.549      -0.198       0.105
# ==============================================================================
# Omnibus:                      250.399   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1548.122
# Skew:                           0.481   Prob(JB):                         0.00
# Kurtosis:                       7.430   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Legal
# System
# &
# Property
# Rights   R-squared (uncentered):                   0.002
# Model:                                        OLS   Adj. R-squared (uncentered):              0.001
# Method:                             Least Squares   F-statistic:                              3.510
# Date:                            Mon, 08 Nov 2021   Prob (F-statistic):                      0.0611
# Time:                                    20:22:04   Log-Likelihood:                         -167.84
# No. Observations:                            1808   AIC:                                      337.7
# Df Residuals:                                1807   BIC:                                      343.2
# Df Model:                                       1
# Covariance Type:                        nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Size
# of
# Government    -0.0336      0.018     -1.874      0.061      -0.069       0.002
# ==============================================================================
# Omnibus:                      305.381   Durbin-Watson:                   2.289
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5990.646
# Skew:                          -0.001   Prob(JB):                         0.00
# Kurtosis:                      11.918   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Legal
# System
# &
# Property
# Rights   R-squared (uncentered):                   0.000
# Model:                                        OLS   Adj. R-squared (uncentered):             -0.001
# Method:                             Least Squares   F-statistic:                            0.03565
# Date:                            Mon, 08 Nov 2021   Prob (F-statistic):                       0.850
# Time:                                    20:22:04   Log-Likelihood:                         -169.58
# No. Observations:                            1808   AIC:                                      341.2
# Df Residuals:                                1807   BIC:                                      346.7
# Df Model:                                       1
# Covariance Type:                        nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Sound
# Money    -0.0027      0.014     -0.189      0.850      -0.031       0.025
# ==============================================================================
# Omnibus:                      307.489   Durbin-Watson:                   2.292
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6122.259
# Skew:                          -0.021   Prob(JB):                         0.00
# Kurtosis:                      12.015   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Legal
# System
# &
# Property
# Rights   R-squared (uncentered):                   0.008
# Model:                                        OLS   Adj. R-squared (uncentered):              0.007
# Method:                             Least Squares   F-statistic:                              14.53
# Date:                            Mon, 08 Nov 2021   Prob (F-statistic):                    0.000143
# Time:                                    20:22:04   Log-Likelihood:                         -162.36
# No. Observations:                            1808   AIC:                                      326.7
# Df Residuals:                                1807   BIC:                                      332.2
# Df Model:                                       1
# Covariance Type:                        nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Freedom
# to
# trade
# internationally    -0.0812      0.021     -3.812      0.000      -0.123      -0.039
# ==============================================================================
# Omnibus:                      315.054   Durbin-Watson:                   2.283
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6659.329
# Skew:                           0.002   Prob(JB):                         0.00
# Kurtosis:                      12.402   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Legal
# System
# &
# Property
# Rights   R-squared (uncentered):                   0.040
# Model:                                        OLS   Adj. R-squared (uncentered):              0.039
# Method:                             Least Squares   F-statistic:                              74.65
# Date:                            Mon, 08 Nov 2021   Prob (F-statistic):                    1.21e-17
# Time:                                    20:22:04   Log-Likelihood:                         -133.00
# No. Observations:                            1808   AIC:                                      268.0
# Df Residuals:                                1807   BIC:                                      273.5
# Df Model:                                       1
# Covariance Type:                        nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Regulation    -0.1892      0.022     -8.640      0.000      -0.232      -0.146
# ==============================================================================
# Omnibus:                      336.391   Durbin-Watson:                   2.299
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8118.243
# Skew:                          -0.101   Prob(JB):                         0.00
# Kurtosis:                      13.379   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Legal
# System
# &
# Property
# Rights   R-squared (uncentered):                   0.001
# Model:                                        OLS   Adj. R-squared (uncentered):              0.000
# Method:                             Least Squares   F-statistic:                              1.482
# Date:                            Mon, 08 Nov 2021   Prob (F-statistic):                       0.224
# Time:                                    20:22:04   Log-Likelihood:                         -168.86
# No. Observations:                            1808   AIC:                                      339.7
# Df Residuals:                                1807   BIC:                                      345.2
# Df Model:                                       1
# Covariance Type:                        nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RGDP
# Per
# Capita    -0.0719      0.059     -1.217      0.224      -0.188       0.044
# ==============================================================================
# Omnibus:                      304.836   Durbin-Watson:                   2.287
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5949.853
# Skew:                          -0.016   Prob(JB):                         0.00
# Kurtosis:                      11.887   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Sound
# Money   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.6664
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.414
# Time:                        20:22:04   Log-Likelihood:                         -1074.9
# No. Observations:                1808   AIC:                                      2152.
# Df Residuals:                    1807   BIC:                                      2157.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Size
# of
# Government     0.0242      0.030      0.816      0.414      -0.034       0.082
# ==============================================================================
# Omnibus:                      449.060   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6412.087
# Skew:                           0.759   Prob(JB):                         0.00
# Kurtosis:                      12.100   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Sound
# Money   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.001
# Method:                 Least Squares   F-statistic:                            0.03565
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.850
# Time:                        20:22:04   Log-Likelihood:                         -1075.2
# No. Observations:                1808   AIC:                                      2152.
# Df Residuals:                    1807   BIC:                                      2158.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Legal
# System
# &
# Property
# Rights    -0.0073      0.039     -0.189      0.850      -0.083       0.069
# ==============================================================================
# Omnibus:                      450.160   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6450.606
# Skew:                           0.760   Prob(JB):                         0.00
# Kurtosis:                      12.128   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Sound
# Money   R-squared (uncentered):                   0.016
# Model:                            OLS   Adj. R-squared (uncentered):              0.016
# Method:                 Least Squares   F-statistic:                              30.09
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                    4.70e-08
# Time:                        20:22:04   Log-Likelihood:                         -1060.3
# No. Observations:                1808   AIC:                                      2123.
# Df Residuals:                    1807   BIC:                                      2128.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Freedom
# to
# trade
# internationally    -0.1919      0.035     -5.486      0.000      -0.261      -0.123
# ==============================================================================
# Omnibus:                      455.736   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6919.132
# Skew:                           0.757   Prob(JB):                         0.00
# Kurtosis:                      12.463   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Sound
# Money   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              1.047
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.306
# Time:                        20:22:04   Log-Likelihood:                         -1074.7
# No. Observations:                1808   AIC:                                      2151.
# Df Residuals:                    1807   BIC:                                      2157.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Regulation    -0.0377      0.037     -1.023      0.306      -0.110       0.035
# ==============================================================================
# Omnibus:                      448.026   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6452.560
# Skew:                           0.753   Prob(JB):                         0.00
# Kurtosis:                      12.131   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Sound
# Money   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.001
# Method:                 Least Squares   F-statistic:                            0.08219
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.774
# Time:                        20:22:04   Log-Likelihood:                         -1075.2
# No. Observations:                1808   AIC:                                      2152.
# Df Residuals:                    1807   BIC:                                      2158.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RGDP
# Per
# Capita     0.0279      0.097      0.287      0.774      -0.163       0.219
# ==============================================================================
# Omnibus:                      450.398   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6440.785
# Skew:                           0.762   Prob(JB):                         0.00
# Kurtosis:                      12.120   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                         OLS Regression Results
# =====================================================================================================
# Dep. Variable:     Freedom
# to
# trade
# internationally   R-squared (uncentered):                   0.001
# Model:                                          OLS   Adj. R-squared (uncentered):              0.000
# Method:                               Least Squares   F-statistic:                              1.230
# Date:                              Mon, 08 Nov 2021   Prob (F-statistic):                       0.267
# Time:                                      20:22:04   Log-Likelihood:                         -341.99
# No. Observations:                              1808   AIC:                                      686.0
# Df Residuals:                                  1807   BIC:                                      691.5
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Size
# of
# Government    -0.0219      0.020     -1.109      0.267      -0.061       0.017
# ==============================================================================
# Omnibus:                      499.159   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42876.154
# Skew:                          -0.177   Prob(JB):                         0.00
# Kurtosis:                      26.854   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                         OLS Regression Results
# =====================================================================================================
# Dep. Variable:     Freedom
# to
# trade
# internationally   R-squared (uncentered):                   0.008
# Model:                                          OLS   Adj. R-squared (uncentered):              0.007
# Method:                               Least Squares   F-statistic:                              14.53
# Date:                              Mon, 08 Nov 2021   Prob (F-statistic):                    0.000143
# Time:                                      20:22:04   Log-Likelihood:                         -335.37
# No. Observations:                              1808   AIC:                                      672.7
# Df Residuals:                                  1807   BIC:                                      678.2
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Legal
# System
# &
# Property
# Rights    -0.0983      0.026     -3.812      0.000      -0.149      -0.048
# ==============================================================================
# Omnibus:                      497.313   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42192.078
# Skew:                          -0.173   Prob(JB):                         0.00
# Kurtosis:                      26.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                         OLS Regression Results
# =====================================================================================================
# Dep. Variable:     Freedom
# to
# trade
# internationally   R-squared (uncentered):                   0.016
# Model:                                          OLS   Adj. R-squared (uncentered):              0.016
# Method:                               Least Squares   F-statistic:                              30.09
# Date:                              Mon, 08 Nov 2021   Prob (F-statistic):                    4.70e-08
# Time:                                      20:22:04   Log-Likelihood:                         -327.68
# No. Observations:                              1808   AIC:                                      657.4
# Df Residuals:                                  1807   BIC:                                      662.9
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Sound
# Money    -0.0853      0.016     -5.486      0.000      -0.116      -0.055
# ==============================================================================
# Omnibus:                      512.178   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            50439.419
# Skew:                          -0.155   Prob(JB):                         0.00
# Kurtosis:                      28.874   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                         OLS Regression Results
# =====================================================================================================
# Dep. Variable:     Freedom
# to
# trade
# internationally   R-squared (uncentered):                   0.002
# Model:                                          OLS   Adj. R-squared (uncentered):              0.002
# Method:                               Least Squares   F-statistic:                              3.773
# Date:                              Mon, 08 Nov 2021   Prob (F-statistic):                      0.0522
# Time:                                      20:22:04   Log-Likelihood:                         -340.72
# No. Observations:                              1808   AIC:                                      683.4
# Df Residuals:                                  1807   BIC:                                      688.9
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Regulation    -0.0477      0.025     -1.943      0.052      -0.096       0.000
# ==============================================================================
# Omnibus:                      498.939   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42762.175
# Skew:                          -0.177   Prob(JB):                         0.00
# Kurtosis:                      26.823   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                         OLS Regression Results
# =====================================================================================================
# Dep. Variable:     Freedom
# to
# trade
# internationally   R-squared (uncentered):                   0.001
# Model:                                          OLS   Adj. R-squared (uncentered):              0.000
# Method:                               Least Squares   F-statistic:                              1.061
# Date:                              Mon, 08 Nov 2021   Prob (F-statistic):                       0.303
# Time:                                      20:22:04   Log-Likelihood:                         -342.08
# No. Observations:                              1808   AIC:                                      686.2
# Df Residuals:                                  1807   BIC:                                      691.7
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RGDP
# Per
# Capita    -0.0669      0.065     -1.030      0.303      -0.194       0.060
# ==============================================================================
# Omnibus:                      500.753   Durbin-Watson:                   2.101
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            43328.995
# Skew:                          -0.182   Prob(JB):                         0.00
# Kurtosis:                      26.980   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             Regulation   R-squared (uncentered):                   0.002
# Model:                            OLS   Adj. R-squared (uncentered):              0.001
# Method:                 Least Squares   F-statistic:                              3.048
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                      0.0810
# Time:                        20:22:04   Log-Likelihood:                         -261.40
# No. Observations:                1808   AIC:                                      524.8
# Df Residuals:                    1807   BIC:                                      530.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Size
# of
# Government    -0.0330      0.019     -1.746      0.081      -0.070       0.004
# ==============================================================================
# Omnibus:                      186.024   Durbin-Watson:                   2.240
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1349.869
# Skew:                          -0.144   Prob(JB):                    7.58e-294
# Kurtosis:                       7.223   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             Regulation   R-squared (uncentered):                   0.040
# Model:                            OLS   Adj. R-squared (uncentered):              0.039
# Method:                 Least Squares   F-statistic:                              74.65
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                    1.21e-17
# Time:                        20:22:04   Log-Likelihood:                         -226.33
# No. Observations:                1808   AIC:                                      454.7
# Df Residuals:                    1807   BIC:                                      460.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Legal
# System
# &
# Property
# Rights    -0.2097      0.024     -8.640      0.000      -0.257      -0.162
# ==============================================================================
# Omnibus:                      192.557   Durbin-Watson:                   2.250
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1516.389
# Skew:                          -0.112   Prob(JB):                         0.00
# Kurtosis:                       7.481   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             Regulation   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              1.047
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.306
# Time:                        20:22:04   Log-Likelihood:                         -262.40
# No. Observations:                1808   AIC:                                      526.8
# Df Residuals:                    1807   BIC:                                      532.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Sound
# Money    -0.0154      0.015     -1.023      0.306      -0.045       0.014
# ==============================================================================
# Omnibus:                      184.779   Durbin-Watson:                   2.245
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1333.252
# Skew:                          -0.140   Prob(JB):                    3.08e-290
# Kurtosis:                       7.198   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             Regulation   R-squared (uncentered):                   0.002
# Model:                            OLS   Adj. R-squared (uncentered):              0.002
# Method:                 Least Squares   F-statistic:                              3.773
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                      0.0522
# Time:                        20:22:04   Log-Likelihood:                         -261.04
# No. Observations:                1808   AIC:                                      524.1
# Df Residuals:                    1807   BIC:                                      529.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Freedom
# to
# trade
# internationally    -0.0437      0.022     -1.943      0.052      -0.088       0.000
# ==============================================================================
# Omnibus:                      182.678   Durbin-Watson:                   2.242
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1298.756
# Skew:                          -0.138   Prob(JB):                    9.52e-283
# Kurtosis:                       7.143   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             Regulation   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.001
# Method:                 Least Squares   F-statistic:                            0.02848
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.866
# Time:                        20:22:04   Log-Likelihood:                         -262.91
# No. Observations:                1808   AIC:                                      527.8
# Df Residuals:                    1807   BIC:                                      533.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RGDP
# Per
# Capita     0.0105      0.062      0.169      0.866      -0.111       0.132
# ==============================================================================
# Omnibus:                      182.952   Durbin-Watson:                   2.244
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1305.499
# Skew:                          -0.136   Prob(JB):                    3.27e-284
# Kurtosis:                       7.154   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        RGDP
# Per
# Capita   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.000
# Method:                 Least Squares   F-statistic:                             0.3591
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.549
# Time:                        20:22:04   Log-Likelihood:                          1494.5
# No. Observations:                1808   AIC:                                     -2987.
# Df Residuals:                    1807   BIC:                                     -2982.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Size
# of
# Government    -0.0043      0.007     -0.599      0.549      -0.018       0.010
# ==============================================================================
# Omnibus:                      836.581   Durbin-Watson:                   2.571
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15613.278
# Skew:                          -1.705   Prob(JB):                         0.00
# Kurtosis:                      16.987   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        RGDP
# Per
# Capita   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              1.482
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.224
# Time:                        20:22:04   Log-Likelihood:                          1495.1
# No. Observations:                1808   AIC:                                     -2988.
# Df Residuals:                    1807   BIC:                                     -2983.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Legal
# System
# &
# Property
# Rights    -0.0114      0.009     -1.217      0.224      -0.030       0.007
# ==============================================================================
# Omnibus:                      839.288   Durbin-Watson:                   2.569
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15576.525
# Skew:                          -1.715   Prob(JB):                         0.00
# Kurtosis:                      16.964   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        RGDP
# Per
# Capita   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.001
# Method:                 Least Squares   F-statistic:                            0.08219
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.774
# Time:                        20:22:04   Log-Likelihood:                          1494.4
# No. Observations:                1808   AIC:                                     -2987.
# Df Residuals:                    1807   BIC:                                     -2981.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Sound
# Money     0.0016      0.006      0.287      0.774      -0.010       0.013
# ==============================================================================
# Omnibus:                      834.229   Durbin-Watson:                   2.574
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15545.670
# Skew:                          -1.699   Prob(JB):                         0.00
# Kurtosis:                      16.957   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        RGDP
# Per
# Capita   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              1.061
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.303
# Time:                        20:22:04   Log-Likelihood:                          1494.9
# No. Observations:                1808   AIC:                                     -2988.
# Df Residuals:                    1807   BIC:                                     -2982.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Freedom
# to
# trade
# internationally    -0.0088      0.009     -1.030      0.303      -0.025       0.008
# ==============================================================================
# Omnibus:                      832.077   Durbin-Watson:                   2.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15477.254
# Skew:                          -1.694   Prob(JB):                         0.00
# Kurtosis:                      16.927   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        RGDP
# Per
# Capita   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):             -0.001
# Method:                 Least Squares   F-statistic:                            0.02848
# Date:                Mon, 08 Nov 2021   Prob (F-statistic):                       0.866
# Time:                        20:22:04   Log-Likelihood:                          1494.4
# No. Observations:                1808   AIC:                                     -2987.
# Df Residuals:                    1807   BIC:                                     -2981.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Regulation     0.0015      0.009      0.169      0.866      -0.016       0.019
# ==============================================================================
# Omnibus:                      835.120   Durbin-Watson:                   2.574
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15579.902
# Skew:                          -1.701   Prob(JB):                         0.00
# Kurtosis:                      16.973   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                      Size\nof\nGovernment  \
# Size\nof\nGovernment                                  NaN
# Legal\nSystem\n&\nProperty\nRights                   0.06
# Sound\nMoney                                         0.41
# Freedom\nto\ntrade\ninternationally                  0.27
# Regulation                                           0.08
# RGDP\nPer\nCapita                                    0.55
#
#                                      Legal\nSystem\n&\nProperty\nRights  \
# Size\nof\nGovernment                                               0.06
# Legal\nSystem\n&\nProperty\nRights                                  NaN
# Sound\nMoney                                                       0.85
# Freedom\nto\ntrade\ninternationally                                0.00
# Regulation                                                         0.00
# RGDP\nPer\nCapita                                                  0.22
#
#                                      Sound\nMoney  \
# Size\nof\nGovernment                         0.41
# Legal\nSystem\n&\nProperty\nRights           0.85
# Sound\nMoney                                  NaN
# Freedom\nto\ntrade\ninternationally          0.00
# Regulation                                   0.31
# RGDP\nPer\nCapita                            0.77
#
#                                      Freedom\nto\ntrade\ninternationally  \
# Size\nof\nGovernment                                                0.27
# Legal\nSystem\n&\nProperty\nRights                                  0.00
# Sound\nMoney                                                        0.00
# Freedom\nto\ntrade\ninternationally                                  NaN
# Regulation                                                          0.05
# RGDP\nPer\nCapita                                                   0.30
#
#                                      Regulation  RGDP\nPer\nCapita
# Size\nof\nGovernment                       0.08               0.55
# Legal\nSystem\n&\nProperty\nRights         0.00               0.22
# Sound\nMoney                               0.31               0.77
# Freedom\nto\ntrade\ninternationally        0.05               0.30
# Regulation                                  NaN               0.87
# RGDP\nPer\nCapita                          0.87                NaN

# %% [markdown]
# ## Using Partial Correlations to Build a Causal Skeleton

# %%
undirected_graph = {key:[] for key in df.keys()}
for x in undirected_graph:
    undirected_graph[x] = [y for y in df.keys() if y != x]
        
undirected_graph
# Out:
# {'Size\nof\nGovernment': ['Legal\nSystem\n&\nProperty\nRights',
#   'Sound\nMoney',
#   'Freedom\nto\ntrade\ninternationally',
#   'Regulation',
#   'RGDP\nPer\nCapita'],
#  'Legal\nSystem\n&\nProperty\nRights': ['Size\nof\nGovernment',
#   'Sound\nMoney',
#   'Freedom\nto\ntrade\ninternationally',
#   'Regulation',
#   'RGDP\nPer\nCapita'],
#  'Sound\nMoney': ['Size\nof\nGovernment',
#   'Legal\nSystem\n&\nProperty\nRights',
#   'Freedom\nto\ntrade\ninternationally',
#   'Regulation',
#   'RGDP\nPer\nCapita'],
#  'Freedom\nto\ntrade\ninternationally': ['Size\nof\nGovernment',
#   'Legal\nSystem\n&\nProperty\nRights',
#   'Sound\nMoney',
#   'Regulation',
#   'RGDP\nPer\nCapita'],
#  'Regulation': ['Size\nof\nGovernment',
#   'Legal\nSystem\n&\nProperty\nRights',
#   'Sound\nMoney',
#   'Freedom\nto\ntrade\ninternationally',
#   'RGDP\nPer\nCapita'],
#  'RGDP\nPer\nCapita': ['Size\nof\nGovernment',
#   'Legal\nSystem\n&\nProperty\nRights',
#   'Sound\nMoney',
#   'Freedom\nto\ntrade\ninternationally',
#   'Regulation']}

# %%
import copy

# Removes the links from P because there are no connections for P besides Z
p_val = 0.01
def build_skeleton(df, undirected_graph):
    def check_remaining_controls(control_vars, 
                                 undirected_graph, 
                                 x, 
                                 y, 
                                 controls_used):
        for c_var in control_vars:
            # Sets c_used every time use cycle through new control
            # Program will iterate through remaining controls
            # Until the statistical significance is broken
            c_used = copy.copy(controls_used)
            if y in undirected_graph[x]:
                c_used.append(c_var)
                print(x, y, controls_used)
                test = df.partial_corr(x = x,
                                       y = y, 
                                       covar = c_used,
                                       method = "pearson")
                if test["p-val"].values[0] > p_val:
                    undirected_graph[x].remove(y)
                    break
                else:
                    remaining_controls = copy.copy(control_vars)
                    remaining_controls.remove(c_var)
                    # Recursive function that iterates through remaining variables
                    check_remaining_controls(remaining_controls,
                                             undirected_graph,
                                             x,
                                             y,
                                             c_used)
    for x in df.keys():
        ys = undirected_graph[x]
        for y in df.keys():
            if x != y:
                test = df.partial_corr(x = x,
                                       y = y,
                                       covar = None,
                                       method = "pearson")
                if test["p-val"].values[0] > p_val:
                    undirected_graph[x].remove(y)
                else:
                    control_vars = [z for z in df.keys() if z != y and z != x]
                    check_remaining_controls(control_vars,
                                             undirected_graph,
                                             x, 
                                             y,
                                             [])
    return undirected_graph

build_skeleton(df, undirected_graph)
# Out:
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally []
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Sound\nMoney', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Sound\nMoney', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Regulation', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Regulation', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally []
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'Size\nof\nGovernment', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'Regulation', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'Regulation', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Sound\nMoney', 'RGDP\nPer\nCapita', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally []
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'Size\nof\nGovernment', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'Sound\nMoney', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'Sound\nMoney', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['Regulation', 'RGDP\nPer\nCapita', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally []
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Sound\nMoney', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Sound\nMoney', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Regulation', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Regulation']
# Legal
# System
# &
# Property
# Rights Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Regulation', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation []
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'Sound\nMoney', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'Sound\nMoney', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation []
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Sound\nMoney', 'RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation []
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'Sound\nMoney', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'Sound\nMoney', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation []
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Sound\nMoney', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Sound\nMoney']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Sound\nMoney', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally']
# Legal
# System
# &
# Property
# Rights Regulation ['RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally', 'Sound\nMoney']
# Sound
# Money Freedom
# to
# trade
# internationally []
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Regulation', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'Regulation', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally []
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'Regulation', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'Regulation', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally []
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['Regulation', 'RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally []
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Regulation', 'Size\nof\nGovernment']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Regulation']
# Sound
# Money Freedom
# to
# trade
# internationally ['RGDP\nPer\nCapita', 'Regulation', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights []
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Sound\nMoney', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Sound\nMoney', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Regulation', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Regulation', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights []
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Size\nof\nGovernment', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Regulation', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Regulation', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'RGDP\nPer\nCapita', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights []
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'Size\nof\nGovernment', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'Sound\nMoney', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'Sound\nMoney', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['Regulation', 'RGDP\nPer\nCapita', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights []
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Sound\nMoney', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Sound\nMoney', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Regulation', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Regulation']
# Freedom
# to
# trade
# internationally Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Regulation', 'Sound\nMoney']
# Freedom
# to
# trade
# internationally Sound
# Money []
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'Regulation', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'Regulation', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money []
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'Regulation', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'Regulation', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money []
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'Legal\nSystem\n&\nProperty\nRights', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['Regulation', 'RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money []
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Legal\nSystem\n&\nProperty\nRights', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Regulation', 'Size\nof\nGovernment']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Regulation']
# Freedom
# to
# trade
# internationally Sound
# Money ['RGDP\nPer\nCapita', 'Regulation', 'Legal\nSystem\n&\nProperty\nRights']
# Freedom
# to
# trade
# internationally Regulation []
# Freedom
# to
# trade
# internationally Regulation ['Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights []
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Sound\nMoney', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Sound\nMoney', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Size\nof\nGovernment', 'RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights []
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Sound\nMoney', 'RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights []
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'Sound\nMoney', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'Sound\nMoney', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['Freedom\nto\ntrade\ninternationally', 'RGDP\nPer\nCapita', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights []
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Size\nof\nGovernment', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Sound\nMoney', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Sound\nMoney']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Sound\nMoney', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally', 'Size\nof\nGovernment']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally']
# Regulation Legal
# System
# &
# Property
# Rights ['RGDP\nPer\nCapita', 'Freedom\nto\ntrade\ninternationally', 'Sound\nMoney']
# Regulation Freedom
# to
# trade
# internationally []
# Regulation Freedom
# to
# trade
# internationally ['Size\nof\nGovernment']
# {'Size\nof\nGovernment': [],
#  'Legal\nSystem\n&\nProperty\nRights': ['Freedom\nto\ntrade\ninternationally',
#   'Regulation'],
#  'Sound\nMoney': ['Freedom\nto\ntrade\ninternationally'],
#  'Freedom\nto\ntrade\ninternationally': ['Legal\nSystem\n&\nProperty\nRights',
#   'Sound\nMoney'],
#  'Regulation': ['Legal\nSystem\n&\nProperty\nRights'],
#  'RGDP\nPer\nCapita': []}

# %% [markdown]
# ## Graphing the Skeleton

# %%
import matplotlib.pyplot as plt
import networkx as nx

def graph_DAG(undirected_graph, 
              df, 
              title = "DAG Structure"):
    pcorr_matrix = df.pcorr()
    graph = nx.Graph()
    edges = []
    edge_labels = {}
    for key in undirected_graph:
        # Refers to the first key that there is a correlation with
        for key2 in undirected_graph[key]:
            if (key2, key) not in edges:
                edge = (key, key2)
                edges.append(edge)
                edge_labels[edge] = str(round(pcorr_matrix.loc[key][key2], 2))
    
    graph.add_edges_from(edges)
    # Connects every node in the graph to a color
    # Could use different colors but stick to one in this example
    color_map = ["C0" for g in graph]
    
    fig, ax = plt.subplots(figsize = (30,24))
    # Added the nodes for each edge (2 for each)
    graph.nodes()
    # Formatting
    plt.tight_layout()
    # Automatically generates a graph
    pos = nx.spring_layout(graph)
    
    plt.title(title, fontsize = 30)
    # Draws graph and sets orientation
    nx.draw_networkx(graph,
                     pos,
                     node_color = color_map,
                     node_size = 25000,
                     # Shows node labels
                     with_labels = True,
                     arrows = False,
                     font_size = 20,
                     # Transparency
                     alpha = 1,
                     font_color = "white",
                     ax = ax)
    nx.draw_networkx_edge_labels(graph,
                                 pos,
                                 edge_labels = edge_labels,
                                 font_color = "green",
                                 font_size = 20)
    plt.show()

graph_DAG(undirected_graph, df)

# %% [markdown]
# ## Estimating a Directed Acyclic Graph

# %%
# !pip install pgmpy
from pgmpy.estimators import PC
c = PC(df)
max_cond_vars = len(df.keys()) - 3
# Dag makes sure there is no ambiguity
model = c.estimate(return_type = "dag",
                   # Can use "orig", or "stable" instead of parallel
                   variant = "parallel",
                   significance = p_val,
                   max_cond_vars = max_cond_vars,
                   ci_test = "pearsonr")
edges = model.edges()
edges
# Out:
# Requirement already satisfied: pgmpy in c:\programdata\anaconda3\lib\site-packages (0.1.16)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (2.5)
# Requirement already satisfied: torch in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (1.10.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (4.59.0)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (1.0.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (1.2.4)
# Requirement already satisfied: scipy in c:\users\brand\appdata\roaming\python\python38\site-packages (from pgmpy) (1.7.1)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (0.24.1)
# Requirement already satisfied: statsmodels in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (0.12.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (1.20.1)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from pgmpy) (2.4.7)
# Requirement already satisfied: decorator>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from networkx->pgmpy) (5.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->pgmpy) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->pgmpy) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\programdata\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.1)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch->pgmpy) (3.7.4.3)
#   0%|          | 0/3 [00:00<?, ?it/s]
# OutEdgeView([('Sound\nMoney', 'Freedom\nto\ntrade\ninternationally'), ('Legal\nSystem\n&\nProperty\nRights', 'Freedom\nto\ntrade\ninternationally'), ('Regulation', 'Legal\nSystem\n&\nProperty\nRights')])

# %%
from matplotlib.patches import ArrowStyle

def graph_DAG(edges,
              df,
              title = ""):
    graph = nx.DiGraph()
    
    edge_labels = {}
    for edge in edges:
        controls = [key for key in df.keys() if key not in edge]
        control = list(set(controls))
        keep_controls = []
        for control in controls:
            control_edges = [ctrl_edge for ctrl_edge in edges if control == ctrl_edge[0]]
            if(control, edge[1]) in control_edges:
                # Not needed but good to see what program is doing
                print("keep control:", control)
                keep_controls.append(control)
        print(edge, keep_controls)
        # partial correlation matrix built with nodes from the edge and controls
        pcorr = df[[edge[0], edge[1]] + keep_controls].pcorr().round(2)
        edge_labels[edge] = str(pcorr.loc[edge[1], edge[0]])
        
    graph.add_edges_from(edges)
    color_map = ["C0" for g in graph]
    
    fig, ax = plt.subplots(figsize = (30,24))
    graph.nodes()
    plt.tight_layout()
    pos = nx.spring_layout(graph)
    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, 
                     pos, 
                     node_color = color_map, 
                     node_size = 25000,
                     font_color = "white",
                     font_size = 26, 
                     alpha = 1,
                     width = 1, 
                     edge_color = "C1",
                     arrowstyle = ArrowStyle("Fancy, head_length = 3, head_width = 1.5, tail_width = 0.1"))
    nx.draw_networkx_edge_labels(graph,
                                 pos,
                                 edge_labels = edge_labels,
                                 font_color = "green",
                                 font_size = 20)
    
    plt.show()
graph_DAG(edges, df, title = "Directed Acyclic Graph")
# Out:
# keep control: Legal
# System
# &
# Property
# Rights
# ('Sound\nMoney', 'Freedom\nto\ntrade\ninternationally') ['Legal\nSystem\n&\nProperty\nRights']
# keep control: Sound
# Money
# ('Legal\nSystem\n&\nProperty\nRights', 'Freedom\nto\ntrade\ninternationally') ['Sound\nMoney']
# ('Regulation', 'Legal\nSystem\n&\nProperty\nRights') []
